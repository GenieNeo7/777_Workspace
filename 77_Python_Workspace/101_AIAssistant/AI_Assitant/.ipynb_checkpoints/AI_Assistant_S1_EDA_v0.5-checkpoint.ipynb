# %%
# Library Import

# import jpype, jaydebeapi
import os, sys
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
from pathlib import Path

# %%
# Opthon for jupyter

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

pd.options.display.max_rows = 100
pd.options.display.max_columns = 999
# Out:
# <style>.container { width:100% !important; }</style>

# %%
def saveDataToCSV(file_path, data):
    data.to_csv(file_path, encoding = 'UTF-8', header = True, index = False)

# %%
def readFile(file_path):
#     file = open(file_path, 'r', encoding='UTF-8')
#     data = file.readlines().toString()
#     file.close()
    data = Path(file_path).read_text()
    return data

# %%
def startJVM():
    jar = os.getcwd()+'/lib/ojdbc6.jar'
    args = '-Djava.class.path=%s' % jar
    jvm_path = jpype.getDefaultJVMPath()
    jpype.startJVM(jvm_path, args)

# %%
def getDataFromDatabase(sql):
    query = None
    if(jpype.isJVMStarted()):
        print('JVM Already started')
    else:
        startJVM()
        
    query = readFile(sql)
    print(query)

    conn = jaydebeapi.connect('oracle.jdbc.driver.OracleDriver', 'jdbc:oracle:thin:CUI_APP/cui1234app@10.217.231.120:1524:TE2CUI1')
    curs = conn.cursor()
    curs.execute(query)
    data = pd.read_sql(query,conn)
    return data

# %%
# 대기 중 공정 숫자 체크

def calculWaiting(row):
    temp_cnt = 0    
    for i in row[13:]:
            cnt2 = i.count('_0_')
            cnt3 = i.count('_3_')
            cnt5 = i.count('_5_')
            cnt6 = i.count('_6_')
            temp_cnt += cnt2
            temp_cnt += cnt3
            temp_cnt += cnt5
            temp_cnt += cnt6
    return temp_cnt

# %%
def correctDataRDD(row):
    if(int(row.OPN_HOPE_DATE[:4]) > 2100):
        return row.OPN_HOPE_DATE.replace(row.OPN_HOPE_DATE[:4], '2020')
    else:
        return row.OPN_HOPE_DATE

def correctDataRRDD(row):
    if(int(row.RMVL_HOPE_DATE[:4]) > 2100):
        return row.RMVL_HOPE_DATE.replace(row.RMVL_HOPE_DATE[:4], '2020')
    else:
        return row.RMVL_HOPE_DATE

# %%
def getAbnormalPairList(data):
    all_orderType_list = pna_data_enrich.ORDR_TYPE_ID.tolist()
    all_orderType_set= set(all_orderType_list)
    abnormal_pair = []

    for i in all_orderType_set:
            temp_cnt = 0
            for j in all_orderType_set:
                if(i in j):
                    if('D4' not in j):
                        temp_cnt += 1
            if(temp_cnt > 1):
#                 print(i, temp_cnt)
                abnormal_pair.append(i)
    return abnormal_pair

# %%
def calculateServiceActStatus(row):
    sa_status = row['SA']
    sa_list =sa_status.split('-')
    sa_result = list() 
    lbcs, lnod, lida, lmen = '','','',''
    
    for sa_status in sa_list:
        if('LBCS' in sa_status):
            lbcs = sa_status
        elif('LNOD' in sa_status):
            lnod = sa_status
        elif('LIDA' in sa_status):
            lida = sa_status
        elif('LMEN' in sa_status):
            lmen = sa_status

    if(len(lbcs) > 0):
        sa_result.append(lbcs)
    if(len(lnod) > 0):
        sa_result.append(lnod)
    if(len(lida) > 0):
        sa_result.append(lida)
    if(len(lmen) > 0):
        sa_result.append(lmen)
    if(len(sa_result) < 1):
        sa_result.append('NONE')
         
    return('-'.join(sa_result))

# %%
def calculateLabel(row):
    resultSet = set()
    label = row['Label']
    
    for i in label:
        for j in i:
            resultSet.add(j)
    resultList = list(resultSet)
    
    if(len(resultList) < 1):
        resultList.append('NONE')
    
    return resultList

# %%
# Save Data from Database
sysdate = datetime.today().strftime('%Y%m%d%H%M%S')
SQL_PATH = './sql/AI_Assistant_EDA_PNA_normal.sql'
DATA_PATH = './data'
fileName =  'AI_SIT_PNA_normal_v'+sysdate+'.csv'

# data = getDataFromDatabase(SQL_PATH)
# saveDataToCSV(DATA_PATH + '/' + fileName, data)

# %% [markdown]
# # 1. start of analysis

# %% [markdown]
# ## 1.1 PnA

# %% [markdown]
# ### 1.1.1 File read

# %%
# read data from csv file
# fileName = 'AI_PRD_PNA_normal_v20200928090000.csv'
fileName = 'AI_SIT_PNA_normal_v20200928134000.csv'
input = pd.read_csv(DATA_PATH+'/'+fileName)

# %%
pna_data = input.copy()

# %%
# get basic info
pna_data.describe()
pna_data.info()
pna_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10020 entries, 0 to 10019
# Data columns (total 29 columns):
# QUERY_DATE              10020 non-null object
# CUST_ORDR_NO            10020 non-null object
# CUST_ORDR_VER_NO        10020 non-null int64
# ORDR_COMPOSI_IDFY_ID    10020 non-null object
# LOB                     10020 non-null object
# ORDR_TYPE_ID            10020 non-null object
# CONUTC                  1891 non-null object
# PROD_ID                 10019 non-null object
# PROD_ORDR_SEQ           10020 non-null object
# OBDNG_ID                10020 non-null object
# FIRST_CRET_DT           10020 non-null object
# LAST_CHG_DT             10020 non-null object
# OPN_HOPE_DATE           5629 non-null object
# RMVL_HOPE_DATE          4428 non-null object
# ICIS_CMPLN_DATE         236 non-null object
# LAST_PRCS_EXEC          9994 non-null object
# ORRE                    10012 non-null object
# PRDI                    9927 non-null object
# LORD                    5889 non-null object
# PHRD                    134 non-null object
# RECO                    77 non-null object
# WODI                    402 non-null object
# REAC                    2385 non-null object
# JUJO                    10 non-null object
# SWBO                    22 non-null object
# FUCO                    336 non-null object
# MAUP                    396 non-null object
# ORCN                    237 non-null object
# SA                      9838 non-null object
# dtypes: int64(1), object(28)
# memory usage: 2.2+ MB
#             QUERY_DATE     CUST_ORDR_NO  CUST_ORDR_VER_NO  \
# 0  2020-09-28 13:41:45  11231G318317191                 1
# 1  2020-09-28 13:41:45  14120A001721891                 2
# 2  2020-09-28 13:41:45  14129G007399991                 5
# 3  2020-09-28 13:41:45  14142A107439590                 4
# 4  2020-09-28 13:41:45  14163H208605591                 1
#
#         ORDR_COMPOSI_IDFY_ID       LOB ORDR_TYPE_ID CONUTC PROD_ID  \
# 0            11231G318317191      SOIP           SB    NaN    0V02
# 1    14120A001721891-1065192      PSTN           BA     03    099S
# 2    14129G007399991-1065281      PSTN           B1     03    099S
# 3  14142A1074395-18646433090  INTERNET           OA     59    099S
# 4    14163H208605591-1065613      PSTN           B1    NaN    099S
#
#             PROD_ORDR_SEQ OBDNG_ID        FIRST_CRET_DT          LAST_CHG_DT  \
# 0          10-10557349041   R00432  2020-09-09 14:04:01  2020-09-09 14:04:01
# 1  10-11216267011-1065192   R02471  2014-05-06 07:36:28  2020-09-24 11:06:00
# 2  10-11218253031-1065281   R02471  2014-05-09 16:04:43  2020-09-21 10:21:18
# 3          10-18646433090   R02471  2014-05-22 10:11:02  2020-09-14 17:58:31
# 4  10-11227430081-1065613   R02471  2014-06-12 17:19:46  2020-09-21 10:37:31
#
#          OPN_HOPE_DATE       RMVL_HOPE_DATE ICIS_CMPLN_DATE  \
# 0                  NaN  2011-08-19 16:00:00             NaN
# 1  2014-06-27 12:00:00                  NaN             NaN
# 2  2015-10-26 00:00:00                  NaN             NaN
# 3  2014-05-26 18:00:00                  NaN             NaN
# 4  2014-06-14 18:00:00                  NaN             NaN
#
#         LAST_PRCS_EXEC         ORRE         PRDI         LORD         PHRD  \
# 0  2020-09-09 14:04:03  ORRE_2_OKEY  PRDI_0_OKEY          NaN          NaN
# 1  2015-09-15 10:50:30  ORRE_2_OKEY  PRDI_2_OKEY  LORD_2_OKEY  PHRD_2_OKEY
# 2  2015-10-23 19:56:13  ORRE_2_OKEY  PRDI_2_OKEY  LORD_2_OKEY          NaN
# 3  2015-01-22 19:39:00  ORRE_2_OKEY  PRDI_2_OKEY  LORD_2_OKEY          NaN
# 4  2014-08-12 09:29:34  ORRE_2_OKEY  PRDI_2_OKEY  LORD_2_OKEY  PHRD_2_OKEY
#
#           RECO         WODI REAC JUJO SWBO FUCO MAUP ORCN                SA
# 0          NaN          NaN  NaN  NaN  NaN  NaN  NaN  NaN  LIDA_ST-LIDA_CP-
# 1  RECO_2_OKEY  WODI_2_OKEY  NaN  NaN  NaN  NaN  NaN  NaN               NaN
# 2  RECO_2_OKEY  WODI_2_OKEY  NaN  NaN  NaN  NaN  NaN  NaN               NaN
# 3  RECO_0_OKEY  WODI_2_OKEY  NaN  NaN  NaN  NaN  NaN  NaN  LIDA_ST-LIDA_CP-
# 4  RECO_7_OKEY  WODI_2_OKEY  NaN  NaN  NaN  NaN  NaN  NaN               NaN

# %% [markdown]
# ### 1.1.2 결측치 처리

# %%
pna_data.tail()
# Out:
#                 QUERY_DATE     CUST_ORDR_NO  CUST_ORDR_VER_NO  \
# 10015  2020-09-28 13:41:45      R02471TT279                 1
# 10016  2020-09-28 13:41:45  SUSPDAIPTV40601                 1
# 10017  2020-09-28 13:41:45  SUSPDAIPTV80021                 1
# 10018  2020-09-28 13:41:45  SUSPDAIPTV80280                 1
# 10019  2020-09-28 13:41:45  TESTSLCLI603052                11
#
#       ORDR_COMPOSI_IDFY_ID   LOB ORDR_TYPE_ID CONUTC PROD_ID   PROD_ORDR_SEQ  \
# 10015          R02471TT279  PSTN           TT    NaN    0501  10-10068639806
# 10016      SUSPDAIPTV40601  IPTV           VA    NaN    0701  10-68021873359
# 10017      SUSPDAIPTV80021  IPTV           VA    NaN    0701  10-68021873359
# 10018      SUSPDAIPTV80280  IPTV           VA    NaN    0701  10-68021873359
# 10019      TESTSLCLI603052  IPTV           V1    NaN    0701  10-64097325094
#
#       OBDNG_ID        FIRST_CRET_DT          LAST_CHG_DT        OPN_HOPE_DATE  \
# 10015   R02471  2020-09-16 14:32:03  2020-09-16 14:32:53  2020-09-16 14:31:42
# 10016   R02471  2020-06-01 16:45:08  2020-09-16 14:31:52  2017-10-27 14:00:00
# 10017   R02471  2020-06-02 11:59:06  2020-09-16 17:41:09  2017-10-27 14:00:00
# 10018   R02471  2020-06-02 12:02:18  2020-09-16 17:43:23  2017-10-27 14:00:00
# 10019   R02471  2020-06-04 18:01:07  2020-09-17 18:36:51                  NaN
#
#             RMVL_HOPE_DATE      ICIS_CMPLN_DATE       LAST_PRCS_EXEC  \
# 10015  2020-09-16 14:31:42  2020-09-16 14:32:53  2020-09-16 14:32:50
# 10016                  NaN                  NaN  2020-09-16 14:31:48
# 10017                  NaN                  NaN  2020-09-16 17:41:08
# 10018                  NaN                  NaN  2020-09-16 17:43:22
# 10019  2020-05-29 00:00:00  2020-09-17 18:36:50  2020-09-17 18:36:47
#
#               ORRE         PRDI            LORD PHRD RECO         WODI  \
# 10015          NaN          NaN             NaN  NaN  NaN          NaN
# 10016  ORRE_2_OKEY  PRDI_2_OKEY  LORD_3_LORD997  NaN  NaN  WODI_2_OKEY
# 10017  ORRE_2_OKEY  PRDI_2_OKEY     LORD_2_OKEY  NaN  NaN  WODI_5_OKEY
# 10018  ORRE_2_OKEY  PRDI_2_OKEY     LORD_2_OKEY  NaN  NaN  WODI_2_OKEY
# 10019  ORRE_2_OKEY  PRDI_2_OKEY     LORD_2_OKEY  NaN  NaN          NaN
#
#                  REAC         JUJO SWBO         FUCO         MAUP  \
# 10015             NaN  JUJO_2_OKEY  NaN  FUCO_2_OKEY  MAUP_2_OKEY
# 10016     REAC_2_OKEY          NaN  NaN  FUCO_0_OKEY          NaN
# 10017  REAC_3_REAC044          NaN  NaN          NaN          NaN
# 10018  REAC_3_REAC044          NaN  NaN          NaN          NaN
# 10019             NaN          NaN  NaN          NaN  MAUP_2_OKEY
#
#               ORCN                      SA
# 10015  ORCN_2_OKEY                     NaN
# 10016          NaN  LIDA_ST-LMEN_MENE0004-
# 10017          NaN  LIDA_ST-LMEN_MENE0004-
# 10018          NaN  LIDA_ST-LMEN_MENE0004-
# 10019  ORCN_2_OKEY        LIDA_ST-LMEN_ST-

# %%
# MAX_DATE = '99/12/31 23:59:59'
MAX_DATE = '2099-12-31 23:59:59'

# %%
data = pna_data.isna().sum()
null_column_list = data[data > 0].index
'''
['PROD_ID', 'OPN_HOPE_DATE', 'RMVL_HOPE_DATE', 'ICIS_CMPLN_DATE',
       'LAST_PRCS_EXEC', 'ORRE', 'PRDI', 'LORD', 'PHRD', 'RECO', 'WODI',
       'REAC', 'JUJO', 'SWBO', 'FUCO', 'MAUP', 'ORCN', 'SA']
'''
# dropna
pna_data.dropna(subset=["PROD_ID"], inplace= True)
pna_data.dropna(subset=["LAST_PRCS_EXEC"], inplace= True)

## fill data
# date column
pna_data['OPN_HOPE_DATE'].fillna(pna_data['RMVL_HOPE_DATE'], inplace= True)
pna_data['RMVL_HOPE_DATE'].fillna(pna_data['OPN_HOPE_DATE'], inplace= True)
pna_data['ICIS_CMPLN_DATE'].fillna(MAX_DATE, inplace= True)

# function column

# apply 함수를 사용하여, 각 column에 적용
## not work pna_data.apply(lambda x: x.fillna('NONE_NONE_NONE') if pna_data.columns  != 'SA' else x.fillna('NONE'))

func_column_list = [i for i in pna_data.iloc[:,13:-1].columns]

for i in func_column_list:
    pna_data[i].fillna('NONE_NONE_NONE', inplace = True)

pna_data['SA'].fillna('NONE', inplace = True)

# %%
pna_data.head()
# data = pna_data.isna().sum()
# null_column_list = data[data > 0].index
# null_column_list
# Out:
#             QUERY_DATE     CUST_ORDR_NO  CUST_ORDR_VER_NO  \
# 0  2020-09-28 13:41:45  11231G318317191                 1
# 1  2020-09-28 13:41:45  14120A001721891                 2
# 2  2020-09-28 13:41:45  14129G007399991                 5
# 3  2020-09-28 13:41:45  14142A107439590                 4
# 4  2020-09-28 13:41:45  14163H208605591                 1
#
#         ORDR_COMPOSI_IDFY_ID       LOB ORDR_TYPE_ID CONUTC PROD_ID  \
# 0            11231G318317191      SOIP           SB    NaN    0V02
# 1    14120A001721891-1065192      PSTN           BA     03    099S
# 2    14129G007399991-1065281      PSTN           B1     03    099S
# 3  14142A1074395-18646433090  INTERNET           OA     59    099S
# 4    14163H208605591-1065613      PSTN           B1    NaN    099S
#
#             PROD_ORDR_SEQ OBDNG_ID        FIRST_CRET_DT          LAST_CHG_DT  \
# 0          10-10557349041   R00432  2020-09-09 14:04:01  2020-09-09 14:04:01
# 1  10-11216267011-1065192   R02471  2014-05-06 07:36:28  2020-09-24 11:06:00
# 2  10-11218253031-1065281   R02471  2014-05-09 16:04:43  2020-09-21 10:21:18
# 3          10-18646433090   R02471  2014-05-22 10:11:02  2020-09-14 17:58:31
# 4  10-11227430081-1065613   R02471  2014-06-12 17:19:46  2020-09-21 10:37:31
#
#          OPN_HOPE_DATE       RMVL_HOPE_DATE      ICIS_CMPLN_DATE  \
# 0  2011-08-19 16:00:00  2011-08-19 16:00:00  2099-12-31 23:59:59
# 1  2014-06-27 12:00:00  2014-06-27 12:00:00  2099-12-31 23:59:59
# 2  2015-10-26 00:00:00  2015-10-26 00:00:00  2099-12-31 23:59:59
# 3  2014-05-26 18:00:00  2014-05-26 18:00:00  2099-12-31 23:59:59
# 4  2014-06-14 18:00:00  2014-06-14 18:00:00  2099-12-31 23:59:59
#
#         LAST_PRCS_EXEC         ORRE         PRDI            LORD  \
# 0  2020-09-09 14:04:03  ORRE_2_OKEY  PRDI_0_OKEY  NONE_NONE_NONE
# 1  2015-09-15 10:50:30  ORRE_2_OKEY  PRDI_2_OKEY     LORD_2_OKEY
# 2  2015-10-23 19:56:13  ORRE_2_OKEY  PRDI_2_OKEY     LORD_2_OKEY
# 3  2015-01-22 19:39:00  ORRE_2_OKEY  PRDI_2_OKEY     LORD_2_OKEY
# 4  2014-08-12 09:29:34  ORRE_2_OKEY  PRDI_2_OKEY     LORD_2_OKEY
#
#              PHRD            RECO            WODI            REAC  \
# 0  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 1     PHRD_2_OKEY     RECO_2_OKEY     WODI_2_OKEY  NONE_NONE_NONE
# 2  NONE_NONE_NONE     RECO_2_OKEY     WODI_2_OKEY  NONE_NONE_NONE
# 3  NONE_NONE_NONE     RECO_0_OKEY     WODI_2_OKEY  NONE_NONE_NONE
# 4     PHRD_2_OKEY     RECO_7_OKEY     WODI_2_OKEY  NONE_NONE_NONE
#
#              JUJO            SWBO            FUCO            MAUP  \
# 0  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 1  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 2  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 3  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 4  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
#
# 10015  2020-09-28 13:41:45      R02471TT279                 1
#
#                       ORDR_COMPOSI_IDFY_ID       LOB ORDR_TYPE_ID    CONUTC  \
# 1                  14120A001721891-1065192      PSTN           BA        03
# 2                  14129G007399991-1065281      PSTN           B1        03
# 4                  14163H208605591-1065613      PSTN           B1       NaN
# 5                  14177A408541091-1055586      PSTN           B1       NaN
# 6                  14177A408541391-1055589      PSTN           B1       NaN
# 8                1430394046669-12017256550  INTERNET         OLOK  06525974
# 9                  15086B417732891-1000360      PSTN           KG       NaN
# 14               171555D010285-11430261180  INTERNET           X2        62
# 15        17209HJ86099491-1122012-Reversal      PSTN           B1       NaN
# 35                 19332BC54706991-1091288      PSTN           B1       NaN
# 37                         19345HU5994519N       IOT           UA       NaN
# 47                 20072GL80520091-1122459      PSTN           B1       NaN
# 75                 20191AJ55081591-1073781      PSTN           B1       NaN
# 76                 201929I55088891-1005151      PSTN           B3       NaN
# 77                 20195LT55092691-1091463      PSTN           B1       NaN
# 80                 20199IX55117791-1091475      PSTN           B1       NaN
# 94                 20218FA261388A1-1068827      PSTN           C1       NaN
# 118                202349426257291-1091472      PSTN           B1       NaN
# 751                        20244EL3940509N       IOT           UA        12
# 787              20245EG941419-23749889400  INTERNET         OLOK        56
# 992              20245GB941448-10010553720  INTERNET         XHXG        06
# 993                20245GI26261491-1012670      PSTN           N2       NaN
# 1094               20245GN26261591-1038399      PSTN           K9       NaN
# 1334             20246EY318305-66093687059  INTERNET         XHXG        06
# 1335             20246FA318307-04196006660  INTERNET         XHXG        06
# 1336             20246FF318310-04196006660  INTERNET         XHXG        06
# 1437             20246FP318324-65088355139  INTERNET         XHXG        06
# 1438             20246FS318326-65088355139  INTERNET         XHXG        06
# 1439             20246G7318337-04999121090  INTERNET         XHXG        06
# 1440             20246GD318342-04999121090  INTERNET         XHXG      0618
# 1554             20246I1318626-66102208719  INTERNET         XHXG        06
# 1571             202479N620113-17598234260  INTERNET         XHXG    061839
# 1674             202479R620186-17598234260  INTERNET         ONOM        55
# 1687             202479Y620206-17598234260  INTERNET         XHXG        06
# 1777               20248A8262619A1-1068835      PSTN           C1       NaN
# 1838               20251EX26262091-1083474      PSTN           A1       NaN
# 1862             20252DJ248163-04199148480  INTERNET         XHXG        06
# 1866             20252F8248189-10017615410  INTERNET         XHXG        06
# 1925                       202540S5900299N      SOIP           SA       NaN
# 2476               20258DW26266491-1122679      PSTN           B1       NaN
# 2477               20258DW26266591-1122680      PSTN           B1       NaN
# 2478               20258DW26266691-1122681      PSTN           B1       NaN
# 2479               20258DW26266791-1122682      PSTN           B1       NaN
# 2480               20258DW26266891-1122683      PSTN           B1       NaN
# 2481               20258DW26266991-1122684      PSTN           B1       NaN
# 2482               20258DW26267091-1122685      PSTN           B1       NaN
# 2483               20258DW26267191-1122686      PSTN           B1       NaN
# 2484               20258DW26267291-1122687      PSTN           B1       NaN
# 2485               20258DW26267391-1122688      PSTN           B1       NaN
# 2497               20258EC262677A1-1073810      PSTN           C1       NaN
# ...                                    ...       ...          ...       ...
# 7204               20261FL53524091-1091522      PSTN           B1       NaN
# 7205               20261FN53524291-1133585      PSTN           J1       NaN
# 7336               20261GY53525691-1105095      PSTN           N2       NaN
# 7730               202629S53526091-1003792      PSTN           B3       NaN
# 7731            202629S53526091_EO-1000090      PSTN           EO       NaN
# 7787             20262AK347493-22294751070  INTERNET         XHXG        06
# 7843               20262AK53526491-1018047      PSTN         QBQA       NaN
# 8154             20262BF347757-66103094700  INTERNET         OLOK      5659
# 8156               20262BH53526891-1116063      PSTN           N2       NaN
# 8386             20262DR348474-67106268479  INTERNET         OLOK      5662
# 8393             20262DT348507-66103094700  INTERNET         XHXG        06
# 8394               20262DT535274A1-1045209      PSTN           C1        03
# 8412             20262EB348603-65103102156  INTERNET         OLOK      0656
# 8418               20262EC53527991-1076017      PSTN           J2       NaN
# 8424               20262EH53528091-1062062      PSTN           A1       NaN
# 8425      20262EH53528091-1062062-Reversal      PSTN           B1       NaN
# 8436             20262EW348699-10065520950  INTERNET         XHXG        06
# 8438               20262EY53528191-1122698      PSTN           B1        03
# 8439      20262EY53528191-1122698-Reversal      PSTN           A1       NaN
# 8440               20262EY53528291-1122699      PSTN           B1       NaN
# 8442               20262FC53528491-1012136      PSTN         QBQA       NaN
# 8450               20262FG53528591-1065584      PSTN           E3       NaN
# 8558               20262FT53529191-1062842      PSTN           B1       NaN
# 8559      20262FT53529191-1062842-Reversal      PSTN           A1       NaN
# 8560            20262FT53529191_EO-1000191      PSTN           EO       NaN
# 8561   20262FT53529191_EO-1000191-Reversal      PSTN           EO       NaN
# 8583               20262GD53530091-1004310      PSTN           B3       NaN
# 8584      20262GD53530091-1004310-Reversal      PSTN           A2       NaN
# 8585            20262GD53530091_EO-1000192      PSTN           EO       NaN
# 8586   20262GD53530091_EO-1000192-Reversal      PSTN           EO       NaN
# 8603               20262HA535303A1-1095004      PSTN           C1       NaN
# 8802               202659W53530791-1076160      PSTN           J1       NaN
# 8803               202659W53530891-1076161      PSTN           J1       NaN
# 8804               202659W53530991-1025062      PSTN           J1       NaN
# 8806               202659X53531091-1025063      PSTN           J1       NaN
# 8807               202659X53531191-1025064      PSTN           J1       NaN
# 9054                       20267EG5955319N      SOIP           SA       NaN
# 9064                       20267EG5955419N      SOIP           SA       NaN
# 9117                       20267EG5955949N      SOIP           SA       NaN
# 9122                       20267EG5955999N      SOIP           SA       NaN
# 9138                       20267EG5956159N      SOIP           SA       NaN
# 9215                       20267EU5957389N      SOIP           SA       NaN
# 9245                       20267EU5957689N      SOIP           SA       NaN
# 9275                       20267EU5957989N      SOIP           SA       NaN
# 9333                       20267GT5959759N      SOIP           SB       NaN
# 10008                          R02471TG872  INTERNET         TGRG       NaN
# 10009                          R02471TG873  INTERNET         TGRG       NaN
# 10010                          R02471TG874  INTERNET         TGRG       NaN
# 10012                          R02471TL132      PSTN         TLRL       NaN
# 10015                          R02471TT279      PSTN           TT       NaN
#
#       PROD_ID                       PROD_ORDR_SEQ OBDNG_ID  \
# 1        099S              10-11216267011-1065192   R02471
# 2        099S              10-11218253031-1065281   R02471
ORRE_2_OKEY-ORRE_2_OKEY  PRDI_0_OKEY-PRDI_0_OKEY
# 9                  ORRE_2_OKEY              PRDI_2_OKEY
# 14                 ORRE_2_OKEY              PRDI_2_OKEY
# 15                 ORRE_2_OKEY              PRDI_2_OKEY
# 35                 ORRE_2_OKEY              PRDI_2_OKEY
# 37                 ORRE_2_OKEY              PRDI_2_OKEY
# 47                 ORRE_2_OKEY              PRDI_2_OKEY
# 75                 ORRE_2_OKEY              PRDI_2_OKEY
# 76                 ORRE_2_OKEY              PRDI_2_OKEY
# 77                 ORRE_2_OKEY              PRDI_2_OKEY
# 80                 ORRE_2_OKEY              PRDI_2_OKEY
# 94                 ORRE_2_OKEY              PRDI_2_OKEY
# 118                ORRE_2_OKEY              PRDI_2_OKEY
# 751                ORRE_2_OKEY           NONE_NONE_NONE
# 787    ORRE_2_OKEY-ORRE_2_OKEY  PRDI_0_OKEY-PRDI_0_OKEY
# 992    ORRE_2_OKEY-ORRE_2_OKEY  PRDI_0_OKEY-PRDI_0_OKEY
# 993                ORRE_2_OKEY              PRDI_2_OKEY
# 1094               ORRE_2_OKEY              PRDI_2_OKEY
# 1334   ORRE_2_OKEY-ORRE_2_OKEY  PRDI_0_OKEY-PRDI_0_OKEY
# 1335   ORRE_2_OKEY-ORRE_2_OKEY  PRDI_2_OKEY-PRDI_2_OKEY
# 1336   ORRE_2_OKEY-ORRE_2_OKEY  PRDI_2_OKEY-PRDI_2_OKEY
# 1437   ORRE_2_OKEY-ORRE_2_OKEY  PRDI_0_OKEY-PRDI_0_OKEY
# 1438   ORRE_2_OKEY-ORRE_2_OKEY  PRDI_0_OKEY-PRDI_0_OKEY
# 1439   ORRE_2_OKEY-ORRE_2_OKEY  PRDI_0_OKEY-PRDI_0_OKEY
# 1440   ORRE_2_OKEY-ORRE_2_OKEY  PRDI_0_OKEY-PRDI_0_OKEY
# 1554   ORRE_2_OKEY-ORRE_2_OKEY  PRDI_2_OKEY-PRDI_2_OKEY
# 1571   ORRE_2_OKEY-ORRE_2_OKEY  PRDI_2_OKEY-PRDI_2_OKEY
# 1674   ORRE_2_OKEY-ORRE_2_OKEY  PRDI_2_OKEY-PRDI_2_OKEY
# 1687   ORRE_2_OKEY-ORRE_2_OKEY  PRDI_2_OKEY-PRDI_2_OKEY
# 1777               ORRE_2_OKEY              PRDI_2_OKEY
# 1838               ORRE_2_OKEY              PRDI_2_OKEY
# 1862   ORRE_2_OKEY-ORRE_2_OKEY  PRDI_2_OKEY-PRDI_2_OKEY
# 1866   ORRE_2_OKEY-ORRE_2_OKEY  PRDI_0_OKEY-PRDI_0_OKEY
# 1925               ORRE_2_OKEY              PRDI_2_OKEY
# 2476               ORRE_2_OKEY              PRDI_2_OKEY
# 2477               ORRE_2_OKEY              PRDI_2_OKEY
# 2478               ORRE_2_OKEY              PRDI_2_OKEY
# 2479               ORRE_2_OKEY              PRDI_2_OKEY
# 2480               ORRE_2_OKEY              PRDI_2_OKEY
# 2481               ORRE_2_OKEY              PRDI_2_OKEY
# 2482               ORRE_2_OKEY              PRDI_2_OKEY
# 2483               ORRE_2_OKEY              PRDI_2_OKEY
# 2484               ORRE_2_OKEY              PRDI_2_OKEY
# 2485               ORRE_2_OKEY              PRDI_2_OKEY
# 2497               ORRE_2_OKEY              PRDI_2_OKEY
# ...                        ...                      ...
# 7204               ORRE_2_OKEY              PRDI_2_OKEY
# 7205               ORRE_2_OKEY              PRDI_2_OKEY
# 7336               ORRE_2_OKEY              PRDI_2_OKEY
# 7730               ORRE_2_OKEY              PRDI_2_OKEY
# 7731               ORRE_2_OKEY              PRDI_2_OKEY
# 7787   ORRE_2_OKEY-ORRE_2_OKEY  PRDI_0_OKEY-PRDI_0_OKEY
# 7843   ORRE_2_OKEY-ORRE_2_OKEY  PRDI_2_OKEY-PRDI_2_OKEY
# 8154   ORRE_2_OKEY-ORRE_2_OKEY  PRDI_2_OKEY-PRDI_2_OKEY
# 8156               ORRE_2_OKEY              PRDI_2_OKEY
# 8386   ORRE_2_OKEY-ORRE_2_OKEY  PRDI_2_OKEY-PRDI_2_OKEY
# 8393   ORRE_2_OKEY-ORRE_2_OKEY  PRDI_2_OKEY-PRDI_2_OKEY
# 8394               ORRE_2_OKEY              PRDI_2_OKEY
# 8412   ORRE_2_OKEY-ORRE_2_OKEY  PRDI_2_OKEY-PRDI_2_OKEY
# 8418               ORRE_2_OKEY              PRDI_2_OKEY
# 8424               ORRE_2_OKEY              PRDI_2_OKEY
# 8425               ORRE_2_OKEY              PRDI_2_OKEY
# 8436   ORRE_2_OKEY-ORRE_2_OKEY  PRDI_2_OKEY-PRDI_2_OKEY
# 8438               ORRE_2_OKEY              PRDI_2_OKEY
# 8439               ORRE_2_OKEY              PRDI_2_OKEY
# 8440               ORRE_2_OKEY              PRDI_2_OKEY
# 8442   ORRE_2_OKEY-ORRE_2_OKEY  PRDI_2_OKEY-PRDI_2_OKEY
# 8450               ORRE_2_OKEY              PRDI_2_OKEY
# 8558               ORRE_2_OKEY              PRDI_2_OKEY
# 8559               ORRE_2_OKEY              PRDI_2_OKEY
# 8560               ORRE_2_OKEY              PRDI_2_OKEY
# 8561               ORRE_2_OKEY              PRDI_2_OKEY
# 8583               ORRE_2_OKEY              PRDI_2_OKEY
# 8584               ORRE_2_OKEY              PRDI_2_OKEY
# 8585               ORRE_2_OKEY              PRDI_2_OKEY
# 8586               ORRE_2_OKEY              PRDI_2_OKEY
# 8603               ORRE_2_OKEY              PRDI_2_OKEY
# 8802               ORRE_2_OKEY              PRDI_2_OKEY
# 8803               ORRE_2_OKEY              PRDI_2_OKEY
# 8804               ORRE_2_OKEY              PRDI_2_OKEY
# 8806               ORRE_2_OKEY              PRDI_2_OKEY
# 8807               ORRE_2_OKEY              PRDI_2_OKEY
# 9054               ORRE_2_OKEY           NONE_NONE_NONE
# 9064               ORRE_2_OKEY              PRDI_2_OKEY
# 9117               ORRE_2_OKEY           NONE_NONE_NONE
# 9122               ORRE_2_OKEY           NONE_NONE_NONE
# 9138               ORRE_2_OKEY           NONE_NONE_NONE
# 9215               ORRE_2_OKEY           NONE_NONE_NONE
# 9245               ORRE_2_OKEY           NONE_NONE_NONE
# 9275               ORRE_2_OKEY           NONE_NONE_NONE
# 9333               ORRE_2_OKEY           NONE_NONE_NONE
# 10008           NONE_NONE_NONE           NONE_NONE_NONE
# 10009           NONE_NONE_NONE           NONE_NONE_NONE
# 10010           NONE_NONE_NONE           NONE_NONE_NONE
# 10012           NONE_NONE_NONE           NONE_NONE_NONE
# 10015           NONE_NONE_NONE           NONE_NONE_NONE
#
#                                 LORD                           PHRD  \
# 1                        LORD_2_OKEY                    PHRD_2_OKEY
# 2                        LORD_2_OKEY                 NONE_NONE_NONE
# 4                        LORD_2_OKEY                    PHRD_2_OKEY
# 5                        LORD_2_OKEY                    PHRD_2_OKEY
# 6                        LORD_2_OKEY                    PHRD_2_OKEY
# 8                     NONE_NONE_NONE                 NONE_NONE_NONE
# 9                        LORD_2_OKEY                    PHRD_2_OKEY
# 14                       LORD_2_OKEY                 NONE_NONE_NONE
# 15                    LORD_3_LORD997                 NONE_NONE_NONE
# 35                       LORD_2_OKEY                    PHRD_2_OKEY
# 37                       LORD_2_OKEY                 NONE_NONE_NONE
# 47                       LORD_2_OKEY                    PHRD_2_OKEY
# 75                       LORD_2_OKEY                    PHRD_2_OKEY
# 76                       LORD_2_OKEY                    PHRD_2_OKEY
# 77                       LORD_2_OKEY                    PHRD_2_OKEY
# 80                       LORD_2_OKEY                    PHRD_2_OKEY
# 94                       LORD_2_OKEY                    PHRD_2_OKEY
# 118                      LORD_2_OKEY                    PHRD_2_OKEY
# 751                   NONE_NONE_NONE                 NONE_NONE_NONE
# 787    LORD_3_LORD040-LORD_3_LORD035  PHRD_3_PHRD012-PHRD_3_PHRD404
# 992                   NONE_NONE_NONE                 NONE_NONE_NONE
# 993                   LORD_3_LORD700                 NONE_NONE_NONE
# 1094                  LORD_3_LORD999                 NONE_NONE_NONE
# 1334                  NONE_NONE_NONE                 NONE_NONE_NONE
# 1335   LORD_3_LORD811-LORD_3_LORD811                 NONE_NONE_NONE
# 1336   LORD_3_LORD999-LORD_3_LORD811                 NONE_NONE_NONE
# 1437                  NONE_NONE_NONE                 NONE_NONE_NONE
# 1438                  NONE_NONE_NONE                 NONE_NONE_NONE
# 1439                  NONE_NONE_NONE                 NONE_NONE_NONE
# 1440                  NONE_NONE_NONE                 NONE_NONE_NONE
# 1554   LORD_3_LORD700-LORD_3_LORD700                 NONE_NONE_NONE
# 1571   LORD_3_LORD700-LORD_3_LORD700                 NONE_NONE_NONE
# 1674   LORD_3_LORD700-LORD_3_LORD700                 NONE_NONE_NONE
# 1687   LORD_3_LORD035-LORD_3_LORD035                 NONE_NONE_NONE
# 1777                     LORD_2_OKEY                    PHRD_2_OKEY
# 1838                     LORD_2_OKEY                    PHRD_2_OKEY
# 1862         LORD_2_OKEY-LORD_2_OKEY        PHRD_2_OKEY-PHRD_2_OKEY
# 1866                  NONE_NONE_NONE                 NONE_NONE_NONE
# 1925                     LORD_2_OKEY                 NONE_NONE_NONE
# 2476                     LORD_2_OKEY                 PHRD_3_PHRD011
# 2477                     LORD_2_OKEY                 PHRD_3_PHRD011
# 2478                     LORD_2_OKEY                 PHRD_3_PHRD011
# 2479                     LORD_2_OKEY                 PHRD_3_PHRD011
# 2480                     LORD_2_OKEY                 PHRD_3_PHRD011
# 2481                     LORD_2_OKEY                 PHRD_3_PHRD011
# 2482                     LORD_2_OKEY                 PHRD_3_PHRD011
# 2483                     LORD_2_OKEY                 PHRD_3_PHRD011
# 2484                     LORD_2_OKEY                 PHRD_3_PHRD011
# 2485                     LORD_2_OKEY                 PHRD_3_PHRD011
# 2497                     LORD_2_OKEY                 PHRD_3_PHRD264
# ...                              ...                            ...
# 7204                     LORD_2_OKEY                 NONE_NONE_NONE
# 7205                  LORD_3_LORD700                 NONE_NONE_NONE
# 7336                     LORD_2_OKEY                 NONE_NONE_NONE
# 7730                     LORD_2_OKEY                 NONE_NONE_NONE
# 7731                     LORD_2_OKEY                 NONE_NONE_NONE
# 7787                  NONE_NONE_NONE                 NONE_NONE_NONE
# 7843         LORD_2_OKEY-LORD_2_OKEY                 NONE_NONE_NONE
# 8154         LORD_2_OKEY-LORD_2_OKEY        PHRD_2_OKEY-PHRD_2_OKEY
# 8156                     LORD_2_OKEY                 NONE_NONE_NONE
# 8386         LORD_2_OKEY-LORD_2_OKEY        PHRD_2_OKEY-PHRD_2_OKEY
# 8393         LORD_2_OKEY-LORD_2_OKEY        PHRD_2_OKEY-PHRD_2_OKEY
# 8394                     LORD_2_OKEY                 NONE_NONE_NONE
# 8412   LORD_3_LORD700-LORD_3_LORD700                 NONE_NONE_NONE
# 8418                  LORD_3_LORD101                 NONE_NONE_NONE
# 8424                     LORD_2_OKEY                    PHRD_2_OKEY
# 8425                     LORD_2_OKEY                    PHRD_2_OKEY
# 8436         LORD_2_OKEY-LORD_2_OKEY        PHRD_2_OKEY-PHRD_2_OKEY
# 8438                     LORD_2_OKEY                    PHRD_2_OKEY
# 8439                  LORD_3_LORD600                 NONE_NONE_NONE
# 8440                     LORD_2_OKEY                    PHRD_2_OKEY
# 8442   LORD_3_LORD700-LORD_3_LORD700                 NONE_NONE_NONE
# 8450                  LORD_3_LORD700                 NONE_NONE_NONE
# 8558                     LORD_2_OKEY                 NONE_NONE_NONE
# 8559                     LORD_2_OKEY                 NONE_NONE_NONE
# 8560                     LORD_2_OKEY                 NONE_NONE_NONE
# 8561                     LORD_2_OKEY                 NONE_NONE_NONE
# 8583                     LORD_2_OKEY                 NONE_NONE_NONE
# 8584                     LORD_2_OKEY                 NONE_NONE_NONE
# 8585                     LORD_2_OKEY                 NONE_NONE_NONE
# 8586                     LORD_2_OKEY                 NONE_NONE_NONE
# 8603                     LORD_2_OKEY                 PHRD_3_PHRD011
# 8802                  LORD_3_LORD047                 NONE_NONE_NONE
# 8803                  LORD_3_LORD047                 NONE_NONE_NONE
# 8804                  LORD_3_LORD047                 NONE_NONE_NONE
# 8806                     LORD_2_OKEY                 NONE_NONE_NONE
# 8807                  LORD_3_LORD047                 NONE_NONE_NONE
# ...
# 9275   NONE_NONE_NONE  NONE_NONE_NONE           NONE_NONE_NONE
# 9333   NONE_NONE_NONE  NONE_NONE_NONE           NONE_NONE_NONE
# 10008  NONE_NONE_NONE  NONE_NONE_NONE  REAC_2_OKEY-REAC_7_OKEY
# 10009  NONE_NONE_NONE     WODI_7_OKEY  REAC_2_OKEY-REAC_7_OKEY
# 10010  NONE_NONE_NONE     WODI_6_OKEY  REAC_2_OKEY-REAC_6_OKEY
# 10012  NONE_NONE_NONE  NONE_NONE_NONE  REAC_6_OKEY-REAC_6_OKEY
# 10015  NONE_NONE_NONE  NONE_NONE_NONE           NONE_NONE_NONE
#
#                  JUJO            SWBO            FUCO  \
# 1      NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 2      NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 4      NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 5      NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 6      NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 8      NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 9         JUJO_0_OKEY  NONE_NONE_NONE     FUCO_0_OKEY
# 14     NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 15     NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 35     NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 37     NONE_NONE_NONE  NONE_NONE_NONE     FUCO_0_OKEY
# 47     NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 75     NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 76     NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 77     NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 80     NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 94     NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 118    NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 751    NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 787    NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 992    NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 993    NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 1094   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 1334   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 1335   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 1336   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 1437   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 1438   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 1439   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 1440   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 1554   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 1571   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 1674   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 1687   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 1777   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 1838   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 1862   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 1866   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 1925   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 2476   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 2477   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 2478   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 2479   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 2480   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 2481   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 2482   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 2483   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 2484   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 2485   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 2497   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# ...               ...             ...             ...
# 7204   NONE_NONE_NONE     SWBO_0_OKEY  NONE_NONE_NONE
# 7205   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 7336   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 7730   NONE_NONE_NONE     SWBO_2_OKEY  NONE_NONE_NONE
# 7731   NONE_NONE_NONE     SWBO_2_OKEY  NONE_NONE_NONE
# 7787   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 7843   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 8154   NONE_NONE_NONE  NONE_NONE_NONE     FUCO_2_OKEY
# 8156   NONE_NONE_NONE     SWBO_0_OKEY  NONE_NONE_NONE
# 8386   NONE_NONE_NONE  NONE_NONE_NONE     FUCO_2_OKEY
# 8393   NONE_NONE_NONE  NONE_NONE_NONE     FUCO_2_OKEY
# 8394      JUJO_2_OKEY  NONE_NONE_NONE     FUCO_2_OKEY
# 8412   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 8418   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 8424      JUJO_2_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 8425      JUJO_2_OKEY  NONE_NONE_NONE     FUCO_2_OKEY
# 8436   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 8438   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 8439   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 8440   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 8442   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 8450   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 8558   NONE_NONE_NONE     SWBO_0_OKEY  NONE_NONE_NONE
# 8559   NONE_NONE_NONE     SWBO_0_OKEY  NONE_NONE_NONE
# 8560   NONE_NONE_NONE     SWBO_0_OKEY  NONE_NONE_NONE
# 8561   NONE_NONE_NONE     SWBO_0_OKEY  NONE_NONE_NONE
# 8583   NONE_NONE_NONE     SWBO_0_OKEY  NONE_NONE_NONE
# 8584   NONE_NONE_NONE     SWBO_0_OKEY  NONE_NONE_NONE
# 8585   NONE_NONE_NONE     SWBO_0_OKEY  NONE_NONE_NONE
# 8586   NONE_NONE_NONE     SWBO_0_OKEY  NONE_NONE_NONE
# 8603   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 8802   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 8803   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 8804   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 8806   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 8807   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 9054   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 9064   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 9117   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 9122   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 9138   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 9215   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 9245   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 9275   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 9333   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 10008  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 10009  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 10010  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 10012     JUJO_2_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 10015     JUJO_2_OKEY  NONE_NONE_NONE     FUCO_2_OKEY
#
#                           MAUP                     ORCN    SA  WAITING_NUM  \
# 1               NONE_NONE_NONE           NONE_NONE_NONE  NONE            0
# 2               NONE_NONE_NONE           NONE_NONE_NONE  NONE            0
# 4               NONE_NONE_NONE           NONE_NONE_NONE  NONE            0
# 5               NONE_NONE_NONE           NONE_NONE_NONE  NONE            0
# 6               NONE_NONE_NONE           NONE_NONE_NONE  NONE            0
# 8               NONE_NONE_NONE           NONE_NONE_NONE  NONE            2
# 9                  MAUP_1_OKEY              ORCN_2_OKEY  NONE            3
# 14              NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 15              NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 35              NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 37              NONE_NONE_NONE           NONE_NONE_NONE  NONE            2
# 47              NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 75              NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 76              NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 77              NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 80              NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 94              NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 118             NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 751             NONE_NONE_NONE           NONE_NONE_NONE  NONE            0
# 787             NONE_NONE_NONE           NONE_NONE_NONE  NONE            7
# 992             NONE_NONE_NONE           NONE_NONE_NONE  NONE            2
# 993             NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 1094            NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 1334            NONE_NONE_NONE           NONE_NONE_NONE  NONE            2
# 1335            NONE_NONE_NONE           NONE_NONE_NONE  NONE            2
# 1336            NONE_NONE_NONE           NONE_NONE_NONE  NONE            2
# 1437            NONE_NONE_NONE           NONE_NONE_NONE  NONE            2
# 1438            NONE_NONE_NONE           NONE_NONE_NONE  NONE            2
# 1439            NONE_NONE_NONE           NONE_NONE_NONE  NONE            2
# 1440            NONE_NONE_NONE           NONE_NONE_NONE  NONE            2
# 1554            NONE_NONE_NONE           NONE_NONE_NONE  NONE            2
# 1571            NONE_NONE_NONE           NONE_NONE_NONE  NONE            2
# 1674            NONE_NONE_NONE           NONE_NONE_NONE  NONE            2
# 1687            NONE_NONE_NONE           NONE_NONE_NONE  NONE            2
# 1777            NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 1838            NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 1862            NONE_NONE_NONE           NONE_NONE_NONE  NONE            3
# 1866            NONE_NONE_NONE           NONE_NONE_NONE  NONE            2
# 1925            NONE_NONE_NONE           NONE_NONE_NONE  NONE            0
# 2476            NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 2477            NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 2478            NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 2479            NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 2480            NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 2481            NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 2482            NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 2483            NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 2484            NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 2485            NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 2497            NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# ...                        ...                      ...   ...          ...
# 7204               MAUP_2_OKEY           NONE_NONE_NONE  NONE            1
# 7205            NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 7336            NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 7730               MAUP_2_OKEY              ORCN_2_OKEY  NONE            0
# 7731               MAUP_2_OKEY              ORCN_2_OKEY  NONE            0
# 7787            NONE_NONE_NONE           NONE_NONE_NONE  NONE            2
# 7843               MAUP_2_OKEY  ORCN_2_OKEY-ORCN_2_OKEY  NONE            0
# 8154   MAUP_2_OKEY-MAUP_2_OKEY  ORCN_2_OKEY-ORCN_2_OKEY  NONE            0
# 8156               MAUP_2_OKEY           NONE_NONE_NONE  NONE            1
# 8386   MAUP_2_OKEY-MAUP_2_OKEY  ORCN_2_OKEY-ORCN_2_OKEY  NONE            0
# 8393   MAUP_2_OKEY-MAUP_2_OKEY  ORCN_2_OKEY-ORCN_2_OKEY  NONE            0
# 8394               MAUP_2_OKEY              ORCN_2_OKEY  NONE            0
# 8412            NONE_NONE_NONE           NONE_NONE_NONE  NONE            2
# 8418            NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 8424               MAUP_2_OKEY              ORCN_2_OKEY  NONE            0
# 8425               MAUP_2_OKEY              ORCN_2_OKEY  NONE            0
# 8436            NONE_NONE_NONE           NONE_NONE_NONE  NONE            3
# 8438            NONE_NONE_NONE           NONE_NONE_NONE  NONE            2
# 8439            NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 8440            NONE_NONE_NONE           NONE_NONE_NONE  NONE            2
# 8442            NONE_NONE_NONE           NONE_NONE_NONE  NONE            2
# 8450            NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 8558               MAUP_2_OKEY           NONE_NONE_NONE  NONE            1
# 8559               MAUP_2_OKEY           NONE_NONE_NONE  NONE            1
# 8560               MAUP_2_OKEY           NONE_NONE_NONE  NONE            1
# 8561               MAUP_2_OKEY           NONE_NONE_NONE  NONE            1
# 8583               MAUP_2_OKEY           NONE_NONE_NONE  NONE            1
# 8584               MAUP_2_OKEY           NONE_NONE_NONE  NONE            1
# 8585               MAUP_2_OKEY           NONE_NONE_NONE  NONE            1
# 8586               MAUP_2_OKEY           NONE_NONE_NONE  NONE            1
# 8603            NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 8802            NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 8803            NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 8804            NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 8806            NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 8807            NONE_NONE_NONE           NONE_NONE_NONE  NONE            1
# 9054            NONE_NONE_NONE           NONE_NONE_NONE  NONE            0
# 9064            NONE_NONE_NONE           NONE_NONE_NONE  NONE            0
# 9117            NONE_NONE_NONE           NONE_NONE_NONE  NONE            0
# 9122            NONE_NONE_NONE           NONE_NONE_NONE  NONE            0
# 9138            NONE_NONE_NONE           NONE_NONE_NONE  NONE            0
# 9215            NONE_NONE_NONE           NONE_NONE_NONE  NONE            0
# 9245            NONE_NONE_NONE           NONE_NONE_NONE  NONE            0
# 9275            NONE_NONE_NONE           NONE_NONE_NONE  NONE            0
# 9333            NONE_NONE_NONE           NONE_NONE_NONE  NONE            0
# 10008              MAUP_2_OKEY  ORCN_2_OKEY-ORCN_2_OKEY  NONE            0
# 10009              MAUP_2_OKEY  ORCN_2_OKEY-ORCN_2_OKEY  NONE            0
# 10010           NONE_NONE_NONE              ORCN_2_OKEY  NONE            2
# 10012           NONE_NONE_NONE           NONE_NONE_NONE  NONE            2
# 10015              MAUP_2_OKEY              ORCN_2_OKEY  NONE            0
#
#       SA_FINAL
# 1         NONE
# 2         NONE
# 4         NONE
# 5         NONE
# 6         NONE
# 8         NONE
# 9         NONE
# 14        NONE
# 15        NONE
# 35        NONE
# 37        NONE
# 47        NONE
# 75        NONE
# 76        NONE
# 77        NONE
# 80        NONE
# 94        NONE
# 118       NONE
# 751       NONE
# 787       NONE
# 992       NONE
# 993       NONE
# 1094      NONE
# 1334      NONE
# 1335      NONE
# 1336      NONE
# 1437      NONE
# 1438      NONE
# 1439      NONE
# 1440      NONE
# 1554      NONE
# 1571      NONE
# 1674      NONE
# 1687      NONE
# 1777      NONE
# 1838      NONE
# 1862      NONE
# 1866      NONE
# 1925      NONE
# 2476      NONE
# 2477      NONE
# 2478      NONE
# 2479      NONE
# 2480      NONE
# 2481      NONE
# 2482      NONE
# 2483      NONE
# 2484      NONE
# 2485      NONE
# 2497      NONE
# ...        ...
# 7204      NONE
# 7205      NONE
# 7336      NONE
# 7730      NONE
# 7731      NONE
# 7787      NONE
# 7843      NONE
# 8154      NONE
# 8156      NONE
# 8386      NONE
# 8393      NONE
# 8394      NONE
# 8412      NONE
# 8418      NONE
# 8424      NONE
# 8425      NONE
# 8436      NONE
# 8438      NONE
# 8439      NONE
# 8440      NONE
# 8442      NONE
# 8450      NONE
# 8558      NONE
# 8559      NONE
# 8560      NONE
# 8561      NONE
# 8583      NONE
# 8584      NONE
# 8585      NONE
# 8586      NONE
# 8603      NONE
# 8802      NONE
# 8803      NONE
# 8804      NONE
# 8806      NONE
# 8807      NONE
# 9054      NONE
# 9064      NONE
# 9117      NONE
# 9122      NONE
# 9138      NONE
# 9215      NONE
# 9245      NONE
# 9275      NONE
# 9333      NONE
# 10008     NONE
# 10009     NONE
# 10010     NONE
# 10012     NONE
# 10015     NONE
#
# [173 rows x 31 columns]

# %%
# pna_data_enrich['QUERY_DATE'] = pd.to_datetime(pna_data_enrich['QUERY_DATE'], format = '%y/%m/%d %H:%M:%S')
# pna_data_enrich['OPN_HOPE_DATE'] = pd.to_datetime(pna_data_enrich['OPN_HOPE_DATE'], format = '%y/%m/%d %H:%M:%S')
# pna_data_enrich['FIRST_CRET_DT'] = pd.to_datetime(pna_data_enrich['FIRST_CRET_DT'], format = '%y/%m/%d %H:%M:%S')
# pna_data_enrich['LAST_CHG_DT'] = pd.to_datetime(pna_data_enrich['LAST_CHG_DT'], format = '%y/%m/%d %H:%M:%S')
# pna_data_enrich['RMVL_HOPE_DATE'] = pd.to_datetime(pna_data_enrich['RMVL_HOPE_DATE'], format = '%y/%m/%d %H:%M:%S')
# pna_data_enrich['ICIS_CMPLN_DATE'] = pd.to_datetime(pna_data_enrich['ICIS_CMPLN_DATE'], format = '%y/%m/%d %H:%M:%S')

# check and replace datetime
pna_data_enrich['OPN_HOPE_DATE'] = pna_data_enrich.apply(lambda row: correctDataRRDD(row), axis= 1)
pna_data_enrich['RMVL_HOPE_DATE'] = pna_data_enrich.apply(lambda row: correctDataRDD(row), axis= 1)

pna_data_enrich['QUERY_DATE'] = pd.to_datetime(pna_data_enrich['QUERY_DATE'], format = '%Y-%m-%d %H:%M:%S')
pna_data_enrich['OPN_HOPE_DATE'] = pd.to_datetime(pna_data_enrich['OPN_HOPE_DATE'], format = '%Y-%m-%d %H:%M:%S')
pna_data_enrich['RMVL_HOPE_DATE'] = pd.to_datetime(pna_data_enrich['RMVL_HOPE_DATE'], format = '%Y-%m-%d %H:%M:%S')
pna_data_enrich['FIRST_CRET_DT'] = pd.to_datetime(pna_data_enrich['FIRST_CRET_DT'], format = '%Y-%m-%d %H:%M:%S')
pna_data_enrich['LAST_CHG_DT'] = pd.to_datetime(pna_data_enrich['LAST_CHG_DT'], format = '%Y-%m-%d %H:%M:%S')
pna_data_enrich['ICIS_CMPLN_DATE'] = pd.to_datetime(pna_data_enrich['ICIS_CMPLN_DATE'], format = '%Y-%m-%d %H:%M:%S')
pna_data_enrich['LAST_PRCS_EXEC'] = pd.to_datetime(pna_data_enrich['LAST_PRCS_EXEC'], format = '%Y-%m-%d %H:%M:%S')

# %%
pna_data_enrich['sysDtLastChgDtDelta'] = (pna_data_enrich['QUERY_DATE'] - pna_data_enrich['LAST_CHG_DT']).astype('timedelta64[m]')
pna_data_enrich['sysDtLastExecDtDelta'] = (pna_data_enrich['QUERY_DATE'] - pna_data_enrich['LAST_PRCS_EXEC']).astype('timedelta64[m]')
pna_data_enrich['hopeDtSysDtDelta'] = (pna_data_enrich['OPN_HOPE_DATE'] - pna_data_enrich['QUERY_DATE']).astype('timedelta64[m]')

# %% [markdown]
# # 이상치 처리
# - 쌍명령 중 1개만 검색 된 것 제외 (트레이닝 데이터 온리)

# %%
abnormalPairList = getAbnormalPairList(pna_data_enrich)

# %%
pna_data_enrich = pna_data_enrich[~pna_data_enrich['ORDR_TYPE_ID'].isin(abnormalPairList)]

# %%
pna_data_enrich['ORDR_TYPE_ID'].value_counts()
# Out:
# SA      3434
# SB      1939
# V1      1053
# SI       958
# O1       625
# OB       473
# VI       267
# S2       208
# VA       149
# OA       139
# UA       115
# U1        93
# S1        70
# VB        46
# B1        45
# VE        31
# XI        28
# UC        28
# VF        25
# OE        23
# WB        20
# OF        19
# XHXG      19
# N2        17
# U2        17
# J1        14
# X1        12
# VC        12
# O2        11
# UI         9
# SC         8
# N3         8
# C1         7
# J2         7
# UB         7
# EO         6
# X2         5
# OLOK       5
# A1         4
# V2         4
# TGRG       3
# B3         3
# XB         3
# I4         2
# XT         2
# QBQA       2
# VT         2
# N1         2
# E3         1
# K9         1
# ONOM       1
# A2         1
# M1         1
# D2         1
# TT         1
# I6         1
# L1         1
# TLRL       1
# L2         1
# KG         1
# KZ         1
# BA         1
# Name: ORDR_TYPE_ID, dtype: int64

# %% [markdown]
# # Anal

# %% [markdown]
# ##### pna_data_enrich['column'].str.contains('abc') or pna_data_enrich['ORRE'].isin(['ORRE_2_OKEY', 'ORRE_2_OKEY-ORRE_2_OKEY'])

# %%
pna_data_group = pna_data_enrich.groupby(['LOB'])['CUST_ORDR_NO']
pna_data_groupAgg = pna_data_group.agg(['count','max','min']).reset_index().sort_values('count')
pna_data_groupAgg.rename(columns = {'count': 'cnt'}, inplace = True)
pna_data_groupAgg
# Out:
#         LOB   cnt              max              min
# 5     WIBRO    20  20268M13245619N  20249M13511609N
# 3      PSTN   130      R02471TT279  14120A001721891
# 1       IOT   269  20270K14884469N  190819V1281949N
# 0  INTERNET  1368      R02471TG874  14142A107439590
# 2      IPTV  1589  TESTSLCLI603052  18085FJ0677209N
# 4      SOIP  6617  20272B86481089N  11231G318317191

# %%
pna_data_group = pna_data_enrich.groupby(['ORDR_TYPE_ID'])['CUST_ORDR_NO']
pna_data_groupAgg = pna_data_group.agg(['count','max','min']).reset_index().sort_values('count')
#column name change
pna_data_groupAgg.rename(columns = {'count': 'cnt'}, inplace = True)
pna_data_groupAgg
# Out:
#    ORDR_TYPE_ID   cnt              max              min
# 29         ONOM     1  202479R6201869N  202479R6201869N
# 14           KG     1  15086B417732891  15086B417732891
# 13           K9     1  20245GN26261591  20245GN26261591
# 17           L2     1  20259EP53500691  20259EP53500691
# 18           M1     1  20259ET53501191  20259ET53501191
# 10           I6     1  20259GD53502091  20259GD53502091
# 15           KZ     1  20259GC53501991  20259GC53501991
# 16           L1     1  20259EP53500691  20259EP53500691
# 6            D2     1  20259GP53502291  20259GP53502291
# 38         TLRL     1      R02471TL132      R02471TL132
# 4            BA     1  14120A001721891  14120A001721891
# 39           TT     1      R02471TT279      R02471TT279
# 1            A2     1  20262GD53530091  20262GD53530091
# 7            E3     1  20262FG53528591  20262FG53528591
# 19           N1     2  20260AS53505991  20260AM53505591
# 54           VT     2  20262G13507919N  20258FS3150549N
# 30         QBQA     2  20262FC53528491  20262AK53526491
# 61           XT     2  20262EI3486489N  20258FG3149439N
# 9            I4     2  20259GX53502691  20259G453501891
# 3            B3     3  20262GD53530091  201929I55088891
# 58           XB     3  20259ER3170209N  14267G557145990
# 37         TGRG     3      R02471TG874      R02471TG872
# 47           V2     4  20262G73508049N  20246HE3185279N
# 0            A1     4  20262FT53529191  20251EX26262091
# 28         OLOK     5  20262EB348603AN  1430394046669A0
# 57           X2     5  20261JP3457249N  171555D0102859N
# 8            EO     6  20262GD53530091  20261FL53523191
# 43           UB     7  20267EJ2314899N  19354FF5402369N
# 12           J2     7  20262EC53527991  20259FD53501491
# 5            C1     7  20262HA535303A1  20218FA261388A1
# 21           N3     8  20260EN53507891  20259EF53500291
# 35           SC     8  20265AB1888209N  20234AA0692369N
# 45           UI     9  20266FV2301729N  20243802680119N
# 23           O2    11  20262FE3500069N  18268AF8695959N
# 50           VC    12  20268H2324302AN  19245BM615383AN
# 56           X1    12  20260IE3413129N  20260EH2048869N
# 11           J1    14  202659X53531191  20259FD53501491
# 20           N2    17  20262BH53526891  20245GI26261491
# 41           U2    17  20270K14884469N  20244K15982549N
# 27           OF    19  20268FJ3242759N  20239GGS4532590
# 59         XHXG    19  20262EW348699AN  20245GB941448AN
# 55           WB    20  20268M13245619N  20249M13511609N
# 26           OE    23  20268FJ324275AN  18051F9666926AN
# 52           VF    25  20262GE3508269N  20246H73185099N
# 60           XI    28  20269IJ5129639N  16GCN2930069190
# 44           UC    28  202686Q3230049N  20147EA5365659N
# 51           VE    31  20262GE350826AN  19261AO075995AN
# 2            B1    45  20262FT53529191  14129G007399991
# 49           VB    46  20272AS6481059N  18085FJ0677209N
# 31           S1    70  20268F65969299N  20244GV5981729N
# 40           U1    93  20267EE2314829N  202445T5970019N
# 42           UA   115  20269FG1140309N  190819V1281949N
# 24           OA   139  20269HR5129559N  14142A107439590
# 48           VA   149  SUSPDAIPTV80280  19051GC4121449N
# 32           S2   208  202729G6476729N  202429F0076419N
# 53           VI   267  20269GP5125929N  20245B49412509N
# 25           OB   473  20272AV6481079N  17341H41156339N
# 22           O1   625  20267ED2314819N  20244GV5981709N
# 36           SI   958  20269EJ5122819N  20083GA9276159N
# 46           V1  1053  TESTSLCLI603052  20246HD3185219N
# 34           SB  1939  20272AD6481019N  11231G318317191
# 33           SA  3434  20272B86481089N  19360GK4003719N

# %%
plt.figure(figsize=(40,20))
plt.bar(pna_data_groupAgg.ORDR_TYPE_ID, pna_data_groupAgg.cnt)
# Out:
# <BarContainer object of 62 artists>

# %%
# Fucntion based

# %%
# pna_data_enrich = pna_data_enrich.loc[(pna_data['ORRE'] == 'ORRE_2_OKEY')  & (pna_data['PRDI'] == 'PRDI_0_OKEY') & (pna_data['LORD'] == 'NONE_NONE_NONE')  & (pna_data['REAC'] == 'NONE_NONE_NONE')
#                 & (pna_data['PHRD'] == 'NONE_NONE_NONE')  & (pna_data['WODI'] == 'NONE_NONE_NONE') & (pna_data['RECO'] == 'NONE_NONE_NONE')  
#                  & (pna_data['FUCO'] == 'NONE_NONE_NONE') & (pna_data['MAUP'] == 'NONE_NONE_NONE')]

# %% [markdown]
# # 4. 데이터 그룹핑
# - 4.2.1 주요 데이터 : LOB 및 WorkOdrTypeCode 등의 Key로 그룹핑
# - 4.2.2 공정 기반 : 공정 기반으로 그룹핑

# %% [markdown]
# ## 4.1 주요 데이터

# %%
# 주요 데이터 - LOB
pna_group_lob = pna_data_enrich.groupby(['LOB'])['CUST_ORDR_NO']
pna_group_lob_agg = pna_group_lob.agg(['count','max','min']).reset_index().sort_values('count')
pna_group_lob_agg.rename(columns = {'count': 'cnt'}, inplace = True)
pna_group_lob_agg
# Out:
#         LOB   cnt              max              min
# 5     WIBRO    20  20268M13245619N  20249M13511609N
# 3      PSTN   130      R02471TT279  14120A001721891
# 1       IOT   269  20270K14884469N  190819V1281949N
# 0  INTERNET  1368      R02471TG874  14142A107439590
# 2      IPTV  1589  TESTSLCLI603052  18085FJ0677209N
# 4      SOIP  6617  20272B86481089N  11231G318317191

# %%
# 주요 데이터 - 오더타입
pna_group_type = pna_data_enrich.groupby(['ORDR_TYPE_ID'])['CUST_ORDR_NO']
pna_group_type_agg = pna_group_type.agg(['count','max','min']).reset_index().sort_values('count')
pna_group_type_agg.rename(columns = {'count': 'cnt'}, inplace = True)
pna_group_type_agg
# Out:
#    ORDR_TYPE_ID   cnt              max              min
# 29         ONOM     1  202479R6201869N  202479R6201869N
# 14           KG     1  15086B417732891  15086B417732891
ORRE', 'PRDI', 'LORD', 'PHRD', 'RECO', 'WODI', 'REAC', 'JUJO', 'SWBO','FUCO', 'MAUP', 'ORCN', 'SA_FINAL'])['CUST_ORDR_NO','ORDR_TYPE_ID','WAITING_NUM']
pna_group_func_agg = pna_group_func.agg(['count','max','min']).reset_index().sort_values([('CUST_ORDR_NO', 'count')])
pna_group_func_agg.rename(columns = {'count': 'cnt'}, inplace = True)

pna_group_func_agg
# Out:
#           LOB ORDR_TYPE_ID         ORRE            PRDI            LORD  \
#
# 0    INTERNET           O1  ORRE_2_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 170      IPTV           VE  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 171      IPTV           VE  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 173      IPTV           VE  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 174      IPTV           VE  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 175      IPTV           VE  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 176      IPTV           VE  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 335      SOIP           SC  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 181      IPTV           VF  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 182      IPTV           VF  ORRE_2_OKEY     PRDI_2_OKEY  LORD_3_LORD700
# 334      SOIP           SC  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 333      SOIP           SC  ORRE_2_OKEY     PRDI_0_OKEY  NONE_NONE_NONE
# 189      IPTV           VI  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 167      IPTV           VC  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 191      IPTV           VI  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 196      IPTV           VT  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 197      PSTN           A1  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 198      PSTN           A1  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 199      PSTN           A1  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 200      PSTN           A1  ORRE_2_OKEY     PRDI_2_OKEY  LORD_3_LORD600
# 201      PSTN           A2  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 202      PSTN           B1  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 205      PSTN           B1  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 208      PSTN           B1  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 210      PSTN           B1  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 212      PSTN           B1  ORRE_2_OKEY     PRDI_2_OKEY  LORD_3_LORD997
# 213      PSTN           B3  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 195      IPTV           VT  ORRE_2_OKEY     PRDI_0_OKEY  NONE_NONE_NONE
# 163      IPTV           VB  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 161      IPTV           VB  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 336      SOIP           SC  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 340      SOIP           SI  ORRE_2_OKEY  NONE_NONE_NONE     LORD_2_OKEY
# 126      IPTV           V1  ORRE_2_OKEY     PRDI_0_OKEY  NONE_NONE_NONE
# 130      IPTV           V1  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 339      SOIP           SI  ORRE_2_OKEY  NONE_NONE_NONE     LORD_2_OKEY
# 132      IPTV           V1  ORRE_2_OKEY     PRDI_2_OKEY  LORD_3_LORD074
# 133      IPTV           V1  ORRE_2_OKEY     PRDI_2_OKEY  LORD_3_LORD700
# 136      IPTV           V2  ORRE_2_OKEY     PRDI_2_OKEY  LORD_3_LORD700
# 137      IPTV           VA  ORRE_2_OKEY  NONE_NONE_NONE     LORD_2_OKEY
# 138      IPTV           VA  ORRE_2_OKEY     PRDI_0_OKEY     LORD_2_OKEY
# 338      SOIP           SC  ORRE_2_OKEY     PRDI_2_OKEY  LORD_3_LORD700
# 140      IPTV           VA  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 141      IPTV           VA  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 142      IPTV           VA  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 144      IPTV           VA  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 146      IPTV           VA  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 147      IPTV           VA  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 148      IPTV           VA  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 149      IPTV           VA  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 150      IPTV           VA  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# ..        ...          ...          ...             ...             ...
# 192      IPTV           VI  ORRE_2_OKEY     PRDI_2_OKEY  LORD_3_LORD700
# 272      SOIP           S2  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 29   INTERNET           OA  ORRE_2_OKEY     PRDI_2_OKEY  LORD_3_LORD075
# 180      IPTV           VF  ORRE_2_OKEY     PRDI_0_OKEY  NONE_NONE_NONE
# 360     WIBRO           WB  ORRE_2_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 265      SOIP           S2  ORRE_2_OKEY     PRDI_0_OKEY  NONE_NONE_NONE
# 351      SOIP           SI  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 28   INTERNET           OA  ORRE_2_OKEY     PRDI_2_OKEY  LORD_3_LORD033
# 15   INTERNET           OA  ORRE_2_OKEY     PRDI_0_OKEY  NONE_NONE_NONE
# 27   INTERNET           OA  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 115       IOT           UC  ORRE_2_OKEY     PRDI_0_OKEY  NONE_NONE_NONE
# 106       IOT           UA  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 187      IPTV           VI  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 256      SOIP           S1  ORRE_2_OKEY     PRDI_0_OKEY  NONE_NONE_NONE
# 349      SOIP           SI  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 344      SOIP           SI  ORRE_2_OKEY     PRDI_0_OKEY  NONE_NONE_NONE
# 160      IPTV           VB  ORRE_2_OKEY     PRDI_0_OKEY  NONE_NONE_NONE
# 257      SOIP           S1  ORRE_2_OKEY     PRDI_0_OKEY  NONE_NONE_NONE
# 288      SOIP           SA  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 292      SOIP           SA  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 154      IPTV           VA  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 267      SOIP           S2  ORRE_2_OKEY     PRDI_0_OKEY  NONE_NONE_NONE
# 139      IPTV           VA  ORRE_2_OKEY     PRDI_0_OKEY  NONE_NONE_NONE
# 359      SOIP           SI  ORRE_2_OKEY     PRDI_2_OKEY  LORD_3_LORD700
# 342      SOIP           SI  ORRE_2_OKEY     PRDI_0_OKEY  NONE_NONE_NONE
# 264      SOIP           S2  ORRE_2_OKEY     PRDI_0_OKEY  NONE_NONE_NONE
# 99        IOT           UA  ORRE_2_OKEY     PRDI_0_OKEY  NONE_NONE_NONE
# 357      SOIP           SI  ORRE_2_OKEY     PRDI_2_OKEY  LORD_3_LORD700
# 90        IOT           U1  ORRE_2_OKEY     PRDI_0_OKEY  NONE_NONE_NONE
# 309      SOIP           SA  ORRE_2_OKEY     PRDI_2_OKEY  LORD_3_LORD997
# 4    INTERNET           O1  ORRE_2_OKEY     PRDI_2_OKEY  LORD_3_LORD091
# 324      SOIP           SB  ORRE_2_OKEY     PRDI_2_OKEY  LORD_3_LORD700
# 291      SOIP           SA  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 325      SOIP           SB  ORRE_2_OKEY     PRDI_2_OKEY  LORD_3_LORD700
# 312      SOIP           SB  ORRE_2_OKEY     PRDI_0_OKEY  NONE_NONE_NONE
# 40   INTERNET           OB  ORRE_2_OKEY     PRDI_2_OKEY  LORD_3_LORD035
# 304      SOIP           SA  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 131      IPTV           V1  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 183      IPTV           VI  ORRE_2_OKEY     PRDI_0_OKEY  NONE_NONE_NONE
# 313      SOIP           SB  ORRE_2_OKEY     PRDI_0_OKEY  NONE_NONE_NONE
# 356      SOIP           SI  ORRE_2_OKEY     PRDI_2_OKEY  LORD_3_LORD700
# 321      SOIP           SB  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 284      SOIP           SA  ORRE_2_OKEY     PRDI_0_OKEY  NONE_NONE_NONE
# 34   INTERNET           OB  ORRE_2_OKEY     PRDI_0_OKEY  NONE_NONE_NONE
# 358      SOIP           SI  ORRE_2_OKEY     PRDI_2_OKEY  LORD_3_LORD700
# 1    INTERNET           O1  ORRE_2_OKEY     PRDI_0_OKEY  NONE_NONE_NONE
# 285      SOIP           SA  ORRE_2_OKEY     PRDI_0_OKEY  NONE_NONE_NONE
# 125      IPTV           V1  ORRE_2_OKEY     PRDI_0_OKEY  NONE_NONE_NONE
# 327      SOIP           SB  ORRE_2_OKEY     PRDI_2_OKEY  LORD_3_LORD700
# 294      SOIP           SA  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
#
#                PHRD            RECO            WODI            REAC  \
#
# 0    NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 170  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 171  NONE_NONE_NONE  NONE_NONE_NONE     WODI_2_OKEY  NONE_NONE_NONE
# 173  NONE_NONE_NONE  NONE_NONE_NONE     WODI_2_OKEY     REAC_2_OKEY
# 174  NONE_NONE_NONE  NONE_NONE_NONE     WODI_2_OKEY     REAC_2_OKEY
# 175  NONE_NONE_NONE  NONE_NONE_NONE     WODI_2_OKEY     REAC_2_OKEY
# 176  NONE_NONE_NONE  NONE_NONE_NONE     WODI_2_OKEY     REAC_2_OKEY
# 335  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 181  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 182  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 334  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 333  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 189  NONE_NONE_NONE  NONE_NONE_NONE     WODI_2_OKEY  NONE_NONE_NONE
# 167  NONE_NONE_NONE  NONE_NONE_NONE     WODI_2_OKEY     REAC_2_OKEY
# 191  NONE_NONE_NONE  NONE_NONE_NONE     WODI_6_OKEY     REAC_2_OKEY
# 196  NONE_NONE_NONE  NONE_NONE_NONE     WODI_6_OKEY  NONE_NONE_NONE
# 197  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 198     PHRD_2_OKEY  NONE_NONE_NONE  NONE_NONE_NONE     REAC_2_OKEY
# 199     PHRD_2_OKEY  NONE_NONE_NONE  NONE_NONE_NONE     REAC_6_OKEY
# 200  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 201  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 202  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 205  NONE_NONE_NONE     RECO_2_OKEY     WODI_2_OKEY  NONE_NONE_NONE
# 208     PHRD_2_OKEY     RECO_2_OKEY     WODI_2_OKEY     REAC_2_OKEY
# 210     PHRD_2_OKEY     RECO_7_OKEY     WODI_7_OKEY  NONE_NONE_NONE
# 212  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 213  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 195  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 163  NONE_NONE_NONE  NONE_NONE_NONE     WODI_2_OKEY  NONE_NONE_NONE
# 161  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 336  NONE_NONE_NONE  NONE_NONE_NONE     WODI_2_OKEY  NONE_NONE_NONE
# 340  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 126  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 130  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 339  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 132  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 133  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 136  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 137  NONE_NONE_NONE  NONE_NONE_NONE     WODI_6_OKEY     REAC_2_OKEY
# 138  NONE_NONE_NONE  NONE_NONE_NONE     WODI_6_OKEY     REAC_2_OKEY
# 338  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 140  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 141  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  REAC_3_REAC044
# 142  NONE_NONE_NONE  NONE_NONE_NONE     WODI_2_OKEY     REAC_2_OKEY
# 144  NONE_NONE_NONE  NONE_NONE_NONE     WODI_2_OKEY     REAC_2_OKEY
# 146  NONE_NONE_NONE  NONE_NONE_NONE     WODI_2_OKEY     REAC_2_OKEY
# 147  NONE_NONE_NONE  NONE_NONE_NONE     WODI_2_OKEY     REAC_2_OKEY
# 148  NONE_NONE_NONE  NONE_NONE_NONE     WODI_2_OKEY  REAC_3_REAC044
# 149  NONE_NONE_NONE  NONE_NONE_NONE     WODI_5_OKEY     REAC_2_OKEY
# 150  NONE_NONE_NONE  NONE_NONE_NONE     WODI_5_OKEY  REAC_3_REAC044
# ..              ...             ...             ...             ...
# 192  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 272  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 29   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 180  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 360  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 265  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 351  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 28   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 15   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 27   PHRD_3_PHRD012  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 115  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 106  NONE_NONE_NONE  NONE_NONE_NONE     WODI_6_OKEY  NONE_NONE_NONE
# 187  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 256  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 349  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 344  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 160  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 257  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 288  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 292  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE     REAC_2_OKEY
# 154  NONE_NONE_NONE  NONE_NONE_NONE     WODI_6_OKEY     REAC_2_OKEY
# 267  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 139  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 359  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 342  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 264  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 99   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 357  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 90   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 309  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 4    NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 324  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 291  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE     REAC_2_OKEY
# 325  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 312  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 40   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 304  NONE_NONE_NONE  NONE_NONE_NONE     WODI_6_OKEY     REAC_2_OKEY
# 131  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 183  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 313  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 356  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 321  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 284  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 34   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 358  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 1    NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 285  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 125  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 327  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 294  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE     REAC_2_OKEY
#
#                JUJO            SWBO            FUCO            MAUP  \
#
# 0    NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 170  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  MAUP_3_MAUP534
# 171  NONE_NONE_NONE  NONE_NONE_NONE     FUCO_2_OKEY  MAUP_3_MAUP534
# 173  NONE_NONE_NONE  NONE_NONE_NONE     FUCO_2_OKEY  MAUP_3_MAUP534
# 174  NONE_NONE_NONE  NONE_NONE_NONE     FUCO_2_OKEY  MAUP_3_MAUP534
# 175  NONE_NONE_NONE  NONE_NONE_NONE     FUCO_2_OKEY  MAUP_3_MAUP536
# 176  NONE_NONE_NONE  NONE_NONE_NONE  FUCO_3_FUCO117  NONE_NONE_NONE
# 335  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 181  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE     MAUP_2_OKEY
# 182  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 334  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE     MAUP_2_OKEY
# 333  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 189  NONE_NONE_NONE  NONE_NONE_NONE     FUCO_2_OKEY     MAUP_2_OKEY
# 167  NONE_NONE_NONE  NONE_NONE_NONE     FUCO_2_OKEY     MAUP_2_OKEY
# 191  NONE_NONE_NONE  NONE_NONE_NONE     FUCO_0_OKEY  NONE_NONE_NONE
# 196  NONE_NONE_NONE  NONE_NONE_NONE     FUCO_0_OKEY  NONE_NONE_NONE
# 197  NONE_NONE_NONE     SWBO_0_OKEY  NONE_NONE_NONE     MAUP_2_OKEY
# 198     JUJO_2_OKEY  NONE_NONE_NONE  NONE_NONE_NONE     MAUP_2_OKEY
# 199  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 200  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 201  NONE_NONE_NONE     SWBO_0_OKEY  NONE_NONE_NONE     MAUP_2_OKEY
# 202  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE     MAUP_2_OKEY
# 205  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 208     JUJO_2_OKEY  NONE_NONE_NONE     FUCO_2_OKEY     MAUP_2_OKEY
# 210  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 212  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 213  NONE_NONE_NONE     SWBO_0_OKEY  NONE_NONE_NONE     MAUP_2_OKEY
# 195  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 163  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE     MAUP_2_OKEY
# 161  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE     MAUP_2_OKEY
# 336  NONE_NONE_NONE  NONE_NONE_NONE     FUCO_2_OKEY     MAUP_2_OKEY
# 340  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 126  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 130  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  MAUP_3_MAUP998
# 339  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 132  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 133  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 136  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 137  NONE_NONE_NONE  NONE_NONE_NONE     FUCO_0_OKEY  NONE_NONE_NONE
# 138  NONE_NONE_NONE  NONE_NONE_NONE     FUCO_0_OKEY  NONE_NONE_NONE
# 338  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 140  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE     MAUP_2_OKEY
# 141  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 142  NONE_NONE_NONE  NONE_NONE_NONE     FUCO_2_OKEY     MAUP_2_OKEY
# 144  NONE_NONE_NONE  NONE_NONE_NONE     FUCO_2_OKEY  MAUP_3_MAUP506
# 146  NONE_NONE_NONE  NONE_NONE_NONE     FUCO_2_OKEY  NONE_NONE_NONE
# 147  NONE_NONE_NONE  NONE_NONE_NONE  FUCO_3_FUCO117  NONE_NONE_NONE
# 148  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 149  NONE_NONE_NONE  NONE_NONE_NONE     FUCO_2_OKEY  MAUP_3_MAUP534
# 150  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# ..              ...             ...             ...             ...
# 192  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 272  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  MAUP_3_MAUP606
# 29   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 180  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 360  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 265  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 351  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 28   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 15   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 27   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 115  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 106  NONE_NONE_NONE  NONE_NONE_NONE     FUCO_0_OKEY  NONE_NONE_NONE
# 187  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 256  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 349  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 344  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 160  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 257  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 288  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 292  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  MAUP_3_MAUP904
# 154  NONE_NONE_NONE  NONE_NONE_NONE     FUCO_0_OKEY  NONE_NONE_NONE
# 267  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 139  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 359  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 342  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 264  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 99   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 357  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 90   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 309  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 4    NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 324  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 291  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE     MAUP_2_OKEY
# 325  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 312  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 40   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 304  NONE_NONE_NONE  NONE_NONE_NONE     FUCO_0_OKEY  NONE_NONE_NONE
# 131  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 183  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 313  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 356  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 321  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 284  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 34   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 358  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 1    NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 285  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 125  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 327  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 294  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
#
#                ORCN               SA_FINAL CUST_ORDR_NO                   \
#                                                     cnt              max
# 0    NONE_NONE_NONE                   NONE            1  20260HB3405119N
# 170  NONE_NONE_NONE        LIDA_ST-LMEN_ST            1  20262FU350764AN
# 171  NONE_NONE_NONE                LIDA_ST            1  20260EM274497AN
# 173  NONE_NONE_NONE  LIDA_ST-LMEN_MENE0005            1  20232GY459633AN
# 174  NONE_NONE_NONE        LIDA_ST-LMEN_ST            1  20147FS536625AN
# 175  NONE_NONE_NONE  LIDA_ST-LMEN_MENE0005            1  20260GB338692AN
# 176  NONE_NONE_NONE        LIDA_ST-LMEN_ST            1  20085MT009547AN
# 335  NONE_NONE_NONE                LIDA_ST            1  20262FU3507659N
# 181     ORCN_2_OKEY                LIDA_ST            1  20262DY348585AN
# 182  NONE_NONE_NONE                LIDA_ST            1  202611H3416809N
# 334     ORCN_2_OKEY        LBCS_CP-LNOD_CP            1  20262DK3484489N
# 333  NONE_NONE_NONE                LIDA_ST            1  20265760960029N
# 189     ORCN_2_OKEY        LIDA_ST-LMEN_ST            1  20258FP3150419N
# 167     ORCN_2_OKEY        LIDA_ST-LMEN_ST            1  20262DR3484819N
# 191  NONE_NONE_NONE        LIDA_ST-LMEN_ST            1  20258GA3150819N
# 196  NONE_NONE_NONE  LIDA_ST-LMEN_MENE0005            1  20258FS3150549N
# 197  NONE_NONE_NONE                   NONE            1  20262FT53529191
# 198     ORCN_2_OKEY                   NONE            1  20262EH53528091
# 199  NONE_NONE_NONE                   NONE            1  20251EX26262091
# 200  NONE_NONE_NONE                   NONE            1  20262EY53528191
# 201  NONE_NONE_NONE                   NONE            1  20262GD53530091
# 202     ORCN_2_OKEY                LNOD_CP            1  202629K53525991
# 205  NONE_NONE_NONE                   NONE            1  14129G007399991
# 208     ORCN_2_OKEY                   NONE            1  20262EH53528091
# 210  NONE_NONE_NONE                   NONE            1  14177A408541391
# 212  NONE_NONE_NONE                   NONE            1  17209HJ86099491
# 213  NONE_NONE_NONE                   NONE            1  20262GD53530091
# 195  NONE_NONE_NONE                LIDA_ST            1  20262G13507919N
# 163     ORCN_2_OKEY        LIDA_ST-LMEN_ST            1  20258FO3150319N
# 161     ORCN_2_OKEY        LIDA_ST-LMEN_ST            1  20262EF3486259N
# 336     ORCN_2_OKEY                LIDA_ST            1  20262DF3477889N
# 340  NONE_NONE_NONE                LIDA_ST            1  20262G53507999N
# 126  NONE_NONE_NONE                   NONE            1  20260HB3405089N
# 130  NONE_NONE_NONE                   NONE            1  20260EG1865119N
# 339  NONE_NONE_NONE        LBCS_ST-LNOD_ST            1  20258E75909169N
# 132  NONE_NONE_NONE  LIDA_ST-LMEN_MENE0005            1  20260H93404179N
# 133  NONE_NONE_NONE  LIDA_ST-LMEN_MENE0005            1  20259DO3168479N
# 136  NONE_NONE_NONE  LIDA_ST-LMEN_MENE0005            1  20259DO3168509N
# 137  NONE_NONE_NONE        LIDA_ST-LMEN_ST            1  202589J3139359N
# 138  NONE_NONE_NONE                LIDA_CP            1  19156HM6553609N
# 338  NONE_NONE_NONE                LBCS_ST            1  202580V5908419N
# 140     ORCN_2_OKEY        LIDA_ST-LMEN_ST            1  20262AE3473389N
# 141  NONE_NONE_NONE                LIDA_ST            1  19261DU3687569N
# 142     ORCN_2_OKEY                LIDA_ST            1  19267GW8787929N
# 144  NONE_NONE_NONE        LIDA_ST-LMEN_ST            1  20206EY3474149N
# 146  NONE_NONE_NONE  LIDA_ST-LMEN_MENE0004            1  20184M56083369N
# 147  NONE_NONE_NONE        LIDA_ST-LMEN_ST            1  20232EE4593959N
# 148  NONE_NONE_NONE  LIDA_ST-LMEN_MENE0004            1  SUSPDAIPTV80280
# 149  NONE_NONE_NONE        LIDA_ST-LMEN_ST            1  20227BB4191659N
# 150  NONE_NONE_NONE  LIDA_ST-LMEN_MENE0004            1  SUSPDAIPTV80021
# ..              ...                    ...          ...              ...
# 192  NONE_NONE_NONE  LIDA_ST-LMEN_MENE0005           17  20266EX2301539N
# 272  NONE_NONE_NONE        LBCS_ST-LNOD_CP           18  202699O5121179N
# 29   NONE_NONE_NONE                LIDA_ST           18  20245HFS4535890
# 180  NONE_NONE_NONE                LIDA_ST           19  20262GE3508269N
# 360  NONE_NONE_NONE                LIDA_ST           20  20268M13245619N
# 265  NONE_NONE_NONE        LBCS_ST-LNOD_CP           21  20269975111649N
# 351  NONE_NONE_NONE                LIDA_ST           22  20261MX3457729N
# 28   NONE_NONE_NONE                LIDA_ST           23  20262GR3511409N
# 15   NONE_NONE_NONE                LIDA_ST           24  20262DR3484789N
# 27   NONE_NONE_NONE                LIDA_ST           24  20268HD1853609N
# 115  NONE_NONE_NONE                LIDA_ST           24  20266JD2302239N
# 106  NONE_NONE_NONE                LIDA_ST           25  20267BO5937089N
# 187  NONE_NONE_NONE  LIDA_ST-LMEN_MENE0005           25  20269GD5125739N
# 256  NONE_NONE_NONE                LBCS_ST           26  20260IC3413049N
# 349  NONE_NONE_NONE                LBCS_ST           30  20268EP5969189N
# 344  NONE_NONE_NONE                LIDA_ST           31  20262EB3486049N
# 160  NONE_NONE_NONE                LIDA_ST           32  20262GO3508499N
# 257  NONE_NONE_NONE                LIDA_ST           33  20260IF3413279N
# 288  NONE_NONE_NONE        LBCS_ST-LNOD_ST           36  20267EU5958149N
# 292  NONE_NONE_NONE                LIDA_ST           46  20272B86481089N
# 154  NONE_NONE_NONE        LIDA_ST-LMEN_ST           50  20262HE3513619N
# 267  NONE_NONE_NONE                LIDA_ST           56  202729G6476729N
# 139  NONE_NONE_NONE                LIDA_ST           62  20262H43513519N
# 359  NONE_NONE_NONE                LIDA_ST           65  20266DO5948849N
# 342  NONE_NONE_NONE                LBCS_ST           67  20269EJ5122819N
# 264  NONE_NONE_NONE                LBCS_ST           69  202709J4882009N
# 99   NONE_NONE_NONE                LIDA_ST           70  20269FG1140309N
# 357  NONE_NONE_NONE                LBCS_ST           74  202699C5974589N
# 90   NONE_NONE_NONE                LIDA_ST           86  20267EE2314829N
# 309  NONE_NONE_NONE        LBCS_ST-LNOD_ST           93  20267EU5958219N
# 4    NONE_NONE_NONE                LIDA_ST           98  20260HH3408099N
# 324  NONE_NONE_NONE        LBCS_CP-LNOD_CP           99  202479R5888339N
# 291     ORCN_2_OKEY        LBCS_CP-LNOD_CP          100  20246DR5884189N
# 325  NONE_NONE_NONE                LBCS_ST          103  20262IB3514039N
# 312  NONE_NONE_NONE                LBCS_ST          107  20272AD6481019N
# 40   NONE_NONE_NONE                LIDA_ST          128  20272AV6481079N
# 304  NONE_NONE_NONE                LBCS_ST          131  20262ID3514079N
# 131  NONE_NONE_NONE  LIDA_ST-LMEN_MENE0005          134  20260HG3408059N
# 183  NONE_NONE_NONE                LIDA_ST          195  20269GP5125929N
# 313  NONE_NONE_NONE        LBCS_ST-LNOD_ST          198  20261BF3437099N
# 356  NONE_NONE_NONE        LBCS_CP-LNOD_CP          198  20246GK5886489N
# 321  NONE_NONE_NONE        LBCS_ST-LNOD_ST          236  20268G85971329N
# 284  NONE_NONE_NONE                LBCS_ST          273  20268EM9859179N
# 34   NONE_NONE_NONE                LIDA_ST          336  20263423518969N
# 358  NONE_NONE_NONE        LBCS_ST-LNOD_ST          431  20268HR5973659N
# 1    NONE_NONE_NONE                LIDA_ST          507  20267ED2314819N
# 285  NONE_NONE_NONE        LBCS_ST-LNOD_ST          784  20272AD6481019N
# 125  NONE_NONE_NONE                LIDA_ST          896  20262G13507909N
# 327  NONE_NONE_NONE        LBCS_ST-LNOD_ST         1161  20268G85970699N
# 294  NONE_NONE_NONE        LBCS_ST-LNOD_ST         1911  20268GH5972379N
#
#                      ORDR_TYPE_ID         WAITING_NUM
#                  min          cnt max min         cnt max min
# 0    20260HB3405119N            1  O1  O1           1   0   0
# 170  20262FU350764AN            1  VE  VE           1   1   1
# 171  20260EM274497AN            1  VE  VE           1   1   1
# 173  20232GY459633AN            1  VE  VE           1   1   1
# 174  20147FS536625AN            1  VE  VE           1   1   1
# 175  20260GB338692AN            1  VE  VE           1   1   1
# 176  20085MT009547AN            1  VE  VE           1   1   1
# 335  20262FU3507659N            1  SC  SC           1   0   0
# 181  20262DY348585AN            1  VF  VF           1   0   0
# 182  202611H3416809N            1  VF  VF           1   1   1
# 334  20262DK3484489N            1  SC  SC           1   0   0
# 333  20265760960029N            1  SC  SC           1   1   1
# 189  20258FP3150419N            1  VI  VI           1   0   0
# 167  20262DR3484819N            1  VC  VC           1   0   0
# 191  20258GA3150819N            1  VI  VI           1   2   2
# 196  20258FS3150549N            1  VT  VT           1   2   2
# 197  20262FT53529191            1  A1  A1           1   1   1
# 198  20262EH53528091            1  A1  A1           1   0   0
# 199  20251EX26262091            1  A1  A1           1   1   1
# 200  20262EY53528191            1  A1  A1           1   1   1
# 201  20262GD53530091            1  A2  A2           1   1   1
# 202  202629K53525991            1  B1  B1           1   0   0
# 205  14129G007399991            1  B1  B1           1   0   0
# 208  20262EH53528091            1  B1  B1           1   0   0
# 210  14177A408541391            1  B1  B1           1   0   0
# 212  17209HJ86099491            1  B1  B1           1   1   1
# 213  20262GD53530091            1  B3  B3           1   1   1
# 195  20262G13507919N            1  VT  VT           1   1   1
# 163  20258FO3150319N            1  VB  VB           1   0   0
# 161  20262EF3486259N            1  VB  VB           1   0   0
# 336  20262DF3477889N            1  SC  SC           1   0   0
# 183  20245B49412509N          195  VI  VI         195   1   1
# 313  20259ET3170219N          198  SB  SB         198   1   1
# 356  20246FL5884389N          198  SI  SI         198   1   1
# 321  20260GR3397519N          236  SB  SB         236   0   0
# 284  20223G25751949N          273  SA  SA         273   1   1
# 34   20237GDS4532490          336  OB  OB         336   1   1
# 358  20244BE5873189N          431  SI  SI         431   1   1
# 1    20244GV5981709N          507  O1  O1         507   1   1
# 285  20238FF4468919N          784  SA  SA         784   1   1
# 125  20246HD3185219N          896  V1  V1         896   1   1
# 327  20245HA5881349N         1161  SB  SB        1161   1   1
# 294  20231GT7544269N         1911  SA  SA        1911   0   0
#
# [361 rows x 24 columns]

# %%
pna_group_func_agg['Label'] = ''
pna_group_func_agg['Label'] = pna_group_func_agg['Label'].apply(list)

# %% [markdown]
# # 5. 오더분석
# - 오더 분석은 정상, 에러(PNA), 오류(Defect)오더로 분류 한다.
# - 기본적인 분석은 공정간 Grouping을 통한 유형 분류를 통해 수행한다.
# - 다양한 오더 유형이 있는 공정 유형이 General하지 않은 경우에는 Detail한 분석을 수행한다.
#  (공정 상태 조건을 통한 오더 정보 수집)
#
#
# ## 5.1 정상 오더 분류
# ### 5.1.1 공통
# ### 5.1.2 LOB
#
# ## 5.2 비정상 오더 분류
# ### 5.2.1 공통
# ### 5.2.2 LOB

# %% [markdown]
# ### 5.1.1 정상 오더 분류
# - 오더 완료

# %%
# ORCN
func_groupAgg_normal_N0001 = pna_group_func_agg.loc[((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() > 3) & 
                                                     (
                                                      (pna_group_func_agg[('ORCN','')] == 'ORCN_2_OKEY-ORCN_2_OKEY') | ((pna_group_func_agg[('ORCN','')] == 'ORCN_2_OKEY') & (pna_group_func_agg[('WAITING_NUM','min')] > 0))
                                                     )
                                                   | ((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() < 3) & (pna_group_func_agg[('ORCN','')].isin(['ORCN_2_OKEY', 'ORCN_7_OKEY']))))]

pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_normal_N0001.index)].Label.apply(lambda x: x.append('N001') or x) 


# SWBO
func_groupAgg_normal_N0002 = pna_group_func_agg.loc[((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() > 3) & 
                                                     (
                                                      (pna_group_func_agg[('SWBO','')] == 'SWBO_0_OKEY-SWBO_0_OKEY') |  ((pna_group_func_agg[('SWBO','')] == 'SWBO_0_OKEY') & (pna_group_func_agg[('ORCN','')] == 'ORCN_2_OKEY'))
                                                     )
                                                   | ((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() < 3) & (pna_group_func_agg[('SWBO','')] == 'SWBO_0_OKEY')))]

pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_normal_N0002.index)].Label.apply(lambda x: x.append('N002') or x) 

# FUCO
func_groupAgg_normal_N0003 = pna_group_func_agg.loc[((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() > 3) & 
                                                     (  
                                                      (pna_group_func_agg[('FUCO','')] == 'FUCO_0_OKEY-FUCO_0_OKEY') |  ((pna_group_func_agg[('FUCO','')] == 'FUCO_0_OKEY') & (pna_group_func_agg[('WAITING_NUM','min')] > 0))
                                                     )
                                                   | ((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() < 3) & (pna_group_func_agg[('FUCO','')] == 'FUCO_0_OKEY')))]

pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_normal_N0003.index)].Label.apply(lambda x: x.append('N003') or x) 

# JUJO
func_groupAgg_normal_N0004 = pna_group_func_agg.loc[((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() > 3) & 
                                                     (
                                                      (pna_group_func_agg[('JUJO','')] == 'JUJO_0_OKEY-JUJO_0_OKEY') |  ((pna_group_func_agg[('JUJO','')] == 'JUJO_0_OKEY') & (pna_group_func_agg[('WAITING_NUM','min')] > 0))
                                                     )
                                                   | ((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() < 3) & (pna_group_func_agg[('JUJO','')] == 'JUJO_0_OKEY')))]

pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_normal_N0004.index)].Label.apply(lambda x: x.append('N004') or x) 

# REAC
func_groupAgg_normal_N0005 = pna_group_func_agg.loc[((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() > 3) & 
                                                     (
                                                      (pna_group_func_agg[('REAC','')].isin(['REAC_6_OKEY-REAC_6_OKEY', 'REAC_0_OKEY-REAC_0_OKEY', 'REAC_0_OKEY-REAC_6_OKEY', 'REAC_6_OKEY-REAC_0_OKEY'])) |  ((pna_group_func_agg[('REAC','')].isin(['REAC_0_OKEY', 'REAC_6_OKEY'])) & (pna_group_func_agg[('WAITING_NUM','min')] > 0))
                                                     )
                                                   | ((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() < 3) & (pna_group_func_agg[('REAC','')].isin(['REAC_0_OKEY','REAC_6_OKEY']))))]

pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_normal_N0005.index)].Label.apply(lambda x: x.append('N005') or x) 

# RECO
func_groupAgg_normal_N0006 = pna_group_func_agg.loc[((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() > 3) & 
                                                     (
                                                      (pna_group_func_agg[('RECO','')] == 'RECO_0_OKEY-RECO_0_OKEY') |  ((pna_group_func_agg[('RECO','')] == 'RECO_0_OKEY') & (pna_group_func_agg[('WAITING_NUM','min')] > 0))
                                                     )
                                                   | ((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() < 3) & (pna_group_func_agg[('RECO','')] == 'RECO_0_OKEY')))]

pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_normal_N0006.index)].Label.apply(lambda x: x.append('N006') or x) 

# WODI
func_groupAgg_normal_N0007 = pna_group_func_agg.loc[((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() > 3) & 
                                                     (
                                                      (pna_group_func_agg[('WODI','')] == 'WODI_0_OKEY-WODI_0_OKEY') |  ((pna_group_func_agg[('WODI','')] == 'WODI_0_OKEY') & (pna_group_func_agg[('WAITING_NUM','min')] > 0))
                                                     )
                                                   | ((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() < 3) & (pna_group_func_agg[('WODI','')] == 'WODI_0_OKEY')))]

# WODI additional
func_groupAgg_normal_N0007 = pna_group_func_agg.loc[((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() > 3) & 
                                                     (
                                                      (pna_group_func_agg[('WODI','')] == 'WODI_0_OKEY-WODI_0_OKEY') |  ((pna_group_func_agg[('WODI','')] == 'WODI_6_OKEY') & (pna_group_func_agg[('WAITING_NUM','min')] > 0))
                                                     )
                                                   | ((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() < 3) & (pna_group_func_agg[('WODI','')] == 'WODI_6_OKEY')))]


pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_normal_N0007.index)].Label.apply(lambda x: x.append('N007') or x) 

# PHRD
func_groupAgg_normal_N0008 = pna_group_func_agg.loc[((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() > 3) & 
                                                     (
                                                      (pna_group_func_agg[('PHRD','')] == 'PHRD_0_OKEY-PHRD_0_OKEY') |  ((pna_group_func_agg[('PHRD','')] == 'PHRD_0_OKEY') & (pna_group_func_agg[('WAITING_NUM','min')] > 0))
                                                     )
                                                   | ((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() < 3) & (pna_group_func_agg[('PHRD','')] == 'PHRD_0_OKEY')))]

pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_normal_N0008.index)].Label.apply(lambda x: x.append('N008') or x) 

# LORD
func_groupAgg_normal_N0009 = pna_group_func_agg.loc[((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() > 3) & 
                                                     (
                                                      (pna_group_func_agg[('LORD','')] == 'LORD_0_OKEY-LORD_0_OKEY') |  ((pna_group_func_agg[('LORD','')] == 'LORD_0_OKEY') & (pna_group_func_agg[('WAITING_NUM','min')] > 0))
                                                     )
                                                   | ((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() < 3) & (pna_group_func_agg[('LORD','')] == 'LORD_0_OKEY')))]

pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_normal_N0009.index)].Label.apply(lambda x: x.append('N009') or x) 

# PRDI
func_groupAgg_normal_N0010 = pna_group_func_agg.loc[((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() > 3) & 
                                                     (
                                                      (pna_group_func_agg[('PRDI','')] == 'PRDI_0_OKEY-PRDI_0_OKEY') |  ((pna_group_func_agg[('PRDI','')] == 'PRDI_0_OKEY') & (pna_group_func_agg[('WAITING_NUM','min')] > 0))
                                                     )
                                                   | ((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() < 3) & (pna_group_func_agg[('PRDI','')] == 'PRDI_0_OKEY')))]

pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_normal_N0010.index)].Label.apply(lambda x: x.append('N010') or x)
# Out:
# 333                [N010]
# 195                [N010]
# 126                [N010]
# 138    [N003, N007, N010]
# 266                [N010]
# 283                [N010]
# 226                [N010]
# 243                [N010]
# 332                [N010]
# 314                [N010]
# 58                 [N010]
# 68                 [N010]
# 59                 [N010]
# 14     [N006, N007, N010]
# 98     [N003, N007, N010]
# 44                 [N010]
# 345                [N010]
# 119                [N010]
# 110                [N010]
# 71                 [N010]
# 135                [N010]
# 286                [N010]
# 179          [N001, N010]
# 165                [N010]
# 8                  [N010]
# 343                [N010]
# 315                [N010]
# 169                [N010]
# 66                 [N010]
# 73                 [N010]
# 93                 [N010]
# 54                 [N010]
# 80                 [N010]
# 180                [N010]
# 265                [N010]
# 15                 [N010]
# 115                [N010]
# 256                [N010]
# 344                [N010]
# 160                [N010]
# 257                [N010]
# 267                [N010]
# 139                [N010]
# 342                [N010]
# 264                [N010]
# 99                 [N010]
# 90                 [N010]
# 312                [N010]
# 183                [N010]
# 313                [N010]
# 284                [N010]
# 34                 [N010]
# 1                  [N010]
# 285                [N010]
# 125                [N010]
# Name: Label, dtype: object

# %%
# Special condition for normal order
# Pair Order
func_groupAgg_normal_P0001 = pna_group_func_agg.loc[(pna_group_func_agg[('JUJO','')].isin(['JUJO_0_OKEY-JUJO_2_OKEY', 'JUJO_2_OKEY-JUJO_0_OKEY'])) & (pna_group_func_agg[('FUCO', '')] == 'FUCO_2_OKEY')]
pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_normal_P0001.index)].Label.apply(lambda x: x.append('P0001') or x) 

func_groupAgg_normal_P0002 = pna_group_func_agg.loc[(pna_group_func_agg[('PRDI','')].isin(['PRDI_0_OKEY-PRDI_2_OKEY', 'PRDI_2_OKEY-PRDI_0_OKEY']))]
pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_normal_P0002.index)].Label.apply(lambda x: x.append('P0002') or x) 


func_groupAgg_normal_P0003 = pna_group_func_agg.loc[(pna_group_func_agg[('PRDI','')].isin(['PRDI_0_OKEY-PRDI_2_OKEY', 'PRDI_2_OKEY-PRDI_0_OKEY'])) & (pna_group_func_agg[('WODI', '')] == 'WODI_6_OKEY')]
pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_normal_P0002.index)].Label.apply(lambda x: x.append('P0003') or x) 

func_groupAgg_normal_P0004 = pna_group_func_agg.loc[(pna_group_func_agg[('JUJO','')] == 'JUJO_2_OKEY-JUJO_0_OKEY') & (pna_group_func_agg[('REAC', '')] == 'REAC_2_OKEY-REAC_2_OKEY')]
pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_normal_P0004.index)].Label.apply(lambda x: x.append('P0004') or x)
# Out:
# Series([], Name: Label, dtype: object)

# %%
# Special condition for normal order
# Service activation waiting Order

# DEL Waiting
func_groupAgg_normal_S0001 = pna_group_func_agg.loc[(pna_group_func_agg[('ORRE','')] == 'ORRE_2_OKEY') & (pna_group_func_agg[('LORD', '')] == 'LORD_2_OKEY')
                                                   & (pna_group_func_agg[('SA_FINAL','')].str.contains('LNOD_ST'))]

pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_normal_S0001.index)].Label.apply(lambda x: x.append('S0001') or x) 

# IDMS Waiting
func_groupAgg_normal_S0003 = pna_group_func_agg.loc[(pna_group_func_agg[('ORRE','')] == 'ORRE_2_OKEY')  & (pna_group_func_agg[('LORD', '')] == 'LORD_2_OKEY')
                                                   & (pna_group_func_agg[('SA_FINAL','')] == 'LIDA_ST') & (pna_group_func_agg[('ORDR_TYPE_ID','')].isin(['UA','UB','U1','U2','UC','UI','SC', 'SI', 'SB']))]
pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_normal_S0003.index)].Label.apply(lambda x: x.append('S0003') or x) 

# NO WODI and waiting for BSCMS
func_groupAgg_normal_S0004 = pna_group_func_agg.loc[(pna_group_func_agg[('ORRE','')] == 'ORRE_2_OKEY') & (pna_group_func_agg[('PRDI', '')] == 'PRDI_2_OKEY') & (pna_group_func_agg[('LORD', '')] == 'LORD_2_OKEY')
                                                   & (pna_group_func_agg[('WODI', '')] == 'NONE_NONE_NONE') & (pna_group_func_agg[('SA_FINAL','')] == 'LBCS_ST')]
pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_normal_S0004.index)].Label.apply(lambda x: x.append('S0004') or x) 

# IPTV Timer
func_groupAgg_normal_S0005 = pna_group_func_agg.loc[(pna_group_func_agg[('LOB','')] == 'IPTV')  & (pna_group_func_agg[('ORRE','')] == 'ORRE_2_OKEY') & (pna_group_func_agg[('PRDI', '')] == 'PRDI_2_OKEY') & (pna_group_func_agg[('LORD', '')] == 'LORD_2_OKEY')
                                                   & (pna_group_func_agg[('WODI', '')].isin(['WODI_2_OKEY','NONE_NONE_NONE'])) & ~(pna_group_func_agg[('SA_FINAL','')].str.contains('LMEN_ST'))]
pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_normal_S0005.index)].Label.apply(lambda x: x.append('S0005') or x)
# Out:
# 171          [S0005]
# 173          [S0005]
# 175          [S0005]
# 181    [N001, S0005]
# 130          [S0005]
# 141          [S0005]
# 142    [N001, S0005]
# 146          [S0005]
# 148          [S0005]
# 186          [S0005]
# 188          [S0005]
# 162          [S0005]
# 187          [S0005]
# 131          [S0005]
# Name: Label, dtype: object

# %%
# PNA Error 오더
# MAUP
func_groupAgg_error_E0001 = pna_group_func_agg.loc[(((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() > 3) &
                                                    (
                                                        (pna_group_func_agg[('MAUP','')].str.contains('MAUP_3')) & (pna_group_func_agg[('WAITING_NUM','min')] > 0)
                                                    )
                                                   | ((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() < 3) & (pna_group_func_agg[('MAUP','')].str.contains('MAUP_3')))))]

pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_error_E0001.index)].Label.apply(lambda x: x.append('E0001') or x) 

# FUCO
func_groupAgg_error_E0002 = pna_group_func_agg.loc[(((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() > 3) &
                                                    (
                                                        (pna_group_func_agg[('FUCO','')].str.contains('FUCO_3')) & (pna_group_func_agg[('WAITING_NUM','min')] > 0)
                                                    )
                                                   | ((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() < 3) & (pna_group_func_agg[('FUCO','')].str.contains('FUCO_3')))))]

pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_error_E0002.index)].Label.apply(lambda x: x.append('E0002') or x) 

# REAC
func_groupAgg_error_E0003 = pna_group_func_agg.loc[(((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() > 3) &
                                                    (
                                                        (pna_group_func_agg[('REAC','')].str.contains('REAC_3')) & (pna_group_func_agg[('WAITING_NUM','min')] > 0)
                                                    )
                                                   | ((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() < 3) & (pna_group_func_agg[('REAC','')].str.contains('REAC_3')))))]

pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_error_E0003.index)].Label.apply(lambda x: x.append('E0003') or x) 

# RECO
func_groupAgg_error_E0004 = pna_group_func_agg.loc[(((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() > 3) &
                                                    (
                                                        (pna_group_func_agg[('RECO','')].str.contains('RECO_3')) & (pna_group_func_agg[('WAITING_NUM','min')] > 0)
                                                    )
                                                   | ((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() < 3) & (pna_group_func_agg[('RECO','')].str.contains('RECO_3')))))]

pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_error_E0004.index)].Label.apply(lambda x: x.append('E0004') or x) 

# PHRD
func_groupAgg_error_E0005 = pna_group_func_agg.loc[(((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() > 3) &
                                                    (
                                                        (pna_group_func_agg[('PHRD','')].str.contains('PHRD_3')) & (pna_group_func_agg[('WAITING_NUM','min')] > 0)
                                                    )
                                                   | ((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() < 3) & (pna_group_func_agg[('PHRD','')].str.contains('PHRD_3')))))]

pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_error_E0005.index)].Label.apply(lambda x: x.append('E0005') or x) 

# LORD
func_groupAgg_error_E0006 = pna_group_func_agg.loc[(((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() > 3) &
                                                    (
                                                        (pna_group_func_agg[('LORD','')].str.contains('LORD_3')) & (pna_group_func_agg[('WAITING_NUM','min')] > 0)
                                                    )
                                                   | ((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() < 3) & (pna_group_func_agg[('LORD','')].str.contains('LORD_3')))))]

pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_error_E0006.index)].Label.apply(lambda x: x.append('E0006') or x) 

# PRDI
func_groupAgg_error_E0007 = pna_group_func_agg.loc[(((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() > 3) &
                                                    (
                                                        (pna_group_func_agg[('PRDI','')].str.contains('PRDI_3')) & (pna_group_func_agg[('WAITING_NUM','min')] > 0)
                                                    )
                                                   | ((pna_group_func_agg[('ORDR_TYPE_ID','max')].str.len() < 3) & (pna_group_func_agg[('PRDI','')].str.contains('PRDI_3')))))]

pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_error_E0007.index)].Label.apply(lambda x: x.append('E0007') or x) 

# 미처리
func_groupAgg_error_EP001 = pna_group_func_agg.loc[(pna_group_func_agg[('WODI','')].str.contains('WODI_5'))]
                                                   
pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_error_EP001.index)].Label.apply(lambda x: x.append('EP001') or x)
# Out:
# 149          [E0001, EP001]
# 150          [E0003, EP001]
# 301           [N001, EP001]
# 331    [N001, S0003, EP001]
# 341           [N003, EP001]
# 105    [N003, S0003, EP001]
# 20            [N006, EP001]
# Name: Label, dtype: object

# %%
# Service activation error
func_groupAgg_error_ES001 = pna_group_func_agg.loc[((pna_group_func_agg[('LOB','')] == 'SOIP') & (pna_group_func_agg[('SA_FINAL','')].str.contains('LIDA_0')))]

pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_error_ES001.index)].Label.apply(lambda x: x.append('ES001') or x)
# Out:
# Series([], Name: Label, dtype: object)

# %% [markdown]
# ## 5.2 Defect
# ### 5.2.1 공통

# %%
# Amending 강제 준공
func_groupAgg_defect_D0001 = pna_group_func_agg.loc[(pna_group_func_agg[('PRDI','')].isin(['PRDI_7_OKEY'])) & (pna_group_func_agg[('WAITING_NUM','min')] == 0) 
                                                    & ~(pna_group_func_agg[('ORCN','')].isin(['ORCN_2_OKEY', 'ORCN_2_OKEY-ORCN_2_OKEY']))]

pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_defect_D0001.index)].Label.apply(lambda x: x.append('D0001') or x) 

func_groupAgg_defect_D0001 = pna_group_func_agg.loc[(pna_group_func_agg[('LORD','')].isin(['LORD_7_OKEY'])) & (pna_group_func_agg[('WAITING_NUM','min')] == 0) 
                                                   & ~(pna_group_func_agg[('ORCN','')].isin(['ORCN_2_OKEY', 'ORCN_2_OKEY-ORCN_2_OKEY']))]

pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_defect_D0001.index)].Label.apply(lambda x: x.append('D0001') or x) 

# ORRE Only
func_groupAgg_defect_D0002 = pna_group_func_agg.loc[(pna_group_func_agg[('ORRE','')].isin(['ORRE_2_OKEY', 'ORRE_2_OKEY-ORRE_2_OKEY']))  & (pna_group_func_agg[('PRDI','')] == 'NONE_NONE_NONE') & (pna_group_func_agg[('LORD','')] == 'NONE_NONE_NONE')  & (pna_data_enrich['REAC'] == 'NONE_NONE_NONE')
                & (pna_group_func_agg[('PHRD','')] == 'NONE_NONE_NONE')  & (pna_group_func_agg[('WODI','')] == 'NONE_NONE_NONE') & (pna_group_func_agg[('RECO','')] == 'NONE_NONE_NONE')  
                 & (pna_group_func_agg[('FUCO','')] == 'NONE_NONE_NONE') & (pna_group_func_agg[('MAUP','')] == 'NONE_NONE_NONE')]

pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_defect_D0002.index)].Label.apply(lambda x: x.append('D0002') or x) 

# No inprogress 
func_groupAgg_defect_D0003 = pna_group_func_agg.loc[(pna_group_func_agg[('WAITING_NUM','min')] == 0) & (pna_group_func_agg[('SA_FINAL','')] == 'NONE')
                                                   & ~(pna_group_func_agg[('ORCN','')].isin(['ORCN_2_OKEY', 'ORCN_2_OKEY-ORCN_2_OKEY']))]

pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_defect_D0003.index)].Label.apply(lambda x: x.append('D0003') or x) 


# No inprogress 
func_groupAgg_defect_D0003 = pna_group_func_agg.loc[(pna_group_func_agg[('WAITING_NUM','min')] == 0) & (pna_group_func_agg[('SA_FINAL','')] == 'NONE')
                                                   & ~(pna_group_func_agg[('ORCN','')].isin(['ORCN_2_OKEY', 'ORCN_2_OKEY-ORCN_2_OKEY']))]

pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_defect_D0003.index)].Label.apply(lambda x: x.append('D0003') or x) 


# LORD 001 status 
func_groupAgg_defect_DS001 = pna_group_func_agg.loc[(pna_group_func_agg[('WAITING_NUM','min')] == 0) & (pna_group_func_agg[('LORD','')].str.contains('LORD_1_OKEY')) 
                                                     &  ~(pna_group_func_agg[('ORCN','')].isin(['ORCN_2_OKEY', 'ORCN_2_OKEY-ORCN_2_OKEY']))]
pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_defect_DS001.index)].Label.apply(lambda x: x.append('DS001') or x)
# Out:
# 316    [DS001]
# Name: Label, dtype: object

# %%
### 5.2.2 LOB WIse

# %%
# IPTV
func_groupAgg_defect_DV001 = pna_group_func_agg.loc[(pna_group_func_agg[('LORD','')].isin(['LORD_2_OKEY'])) & (pna_group_func_agg[('WAITING_NUM','min')] == 0) 
                                                    & (pna_group_func_agg[('SA_FINAL','')].str.contains('LMEN_ST')) & (pna_group_func_agg[('ORCN','')] != 'ORCN_2_OKEY')]
pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_defect_DV001.index)].Label.apply(lambda x: x.append('DV001') or x) 
func_groupAgg_defect_DI001
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-9740bef3985d> in <module>
#       3                                                     & (pna_group_func_agg[('SA_FINAL','')].str.contains('LMEN_ST')) & (pna_group_func_agg[('ORCN','')] != 'ORCN_2_OKEY')]
#       4 pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_defect_DV001.index)].Label.apply(lambda x: x.append('DV001') or x)
# ----> 5 func_groupAgg_defect_DI001
#
# NameError: name 'func_groupAgg_defect_DI001' is not defined

# %%
# Internet

# No inprogress 
func_groupAgg_defect_DI001 = pna_group_func_agg.loc[(pna_group_func_agg[('WAITING_NUM','min')] == 0) & (pna_group_func_agg[('LOB','')] == 'INTERNET') 
                                                     & ~(pna_group_func_agg[('ORCN','')].isin(['ORCN_2_OKEY', 'ORCN_2_OKEY-ORCN_2_OKEY']))]
pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_defect_DI001.index)].Label.apply(lambda x: x.append('DI001') or x) 

func_groupAgg_defect_DI001
# Out:
#          LOB ORDR_TYPE_ID         ORRE            PRDI            LORD  \
#
# 0   INTERNET           O1  ORRE_2_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 42  INTERNET           OB  ORRE_2_OKEY     PRDI_2_OKEY     LORD_7_OKEY
# 16  INTERNET           OA  ORRE_2_OKEY     PRDI_2_OKEY     LORD_2_OKEY
# 33  INTERNET           OA  ORRE_2_OKEY     PRDI_2_OKEY  NONE_NONE_NONE
#
#               PHRD            RECO            WODI            REAC  \
#
# 0   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 42  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 16  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 33  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
#
#               JUJO            SWBO            FUCO            MAUP  \
#
# 0   NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 42  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 16  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 33  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
#
#               ORCN SA_FINAL CUST_ORDR_NO                                    \
#                                      cnt              max              min
# 0   NONE_NONE_NONE     NONE            1  20260HB3405119N  20260HB3405119N
# 42  NONE_NONE_NONE  LIDA_ST            1  17341H41156339N  17341H41156339N
# 16  NONE_NONE_NONE  LIDA_ST            1  170489A76979190  170489A76979190
# 33  NONE_NONE_NONE  LIDA_ST            3  20247AJ6202509N  202479T6201909N
#
#    ORDR_TYPE_ID         WAITING_NUM                                 Label
#             cnt max min         cnt max min
# 0             1  O1  O1           1   0   0  [D0002, D0003, D0003, DI001]
# 42            1  OB  OB           1   0   0                [D0001, DI001]
# 16            1  OA  OA           1   0   0                       [DI001]
# 33            3  OA  OA           3   0   0                       [DI001]

# %%
# SOIP & IOT

# No inprogress 
func_groupAgg_defect_DS001 = pna_group_func_agg.loc[(pna_group_func_agg[('WAITING_NUM','min')] == 0) & (pna_group_func_agg[('LOB','')].isin(['IOT', 'SOIP']))
                                                    & (pna_group_func_agg[('PRDI','')] == 'PRDI_2_OKEY') 
                                                     & (pna_group_func_agg[('LORD','')] == 'NONE_NONE_NONE')  & ~(pna_group_func_agg[('ORCN','')].isin(['ORCN_2_OKEY', 'ORCN_2_OKEY-ORCN_2_OKEY']))]
pna_group_func_agg[pna_group_func_agg.index.isin(func_groupAgg_defect_DS001.index)].Label.apply(lambda x: x.append('DS001') or x) 

func_groupAgg_defect_DS001
# Out:
#       LOB ORDR_TYPE_ID         ORRE         PRDI            LORD  \
#
# 124   IOT           UI  ORRE_2_OKEY  PRDI_2_OKEY  NONE_NONE_NONE
# 277  SOIP           S2  ORRE_2_OKEY  PRDI_2_OKEY  NONE_NONE_NONE
# 310  SOIP           SA  ORRE_2_OKEY  PRDI_2_OKEY  NONE_NONE_NONE
# 109   IOT           UA  ORRE_2_OKEY  PRDI_2_OKEY  NONE_NONE_NONE
# 330  SOIP           SB  ORRE_2_OKEY  PRDI_2_OKEY  NONE_NONE_NONE
#
#                PHRD            RECO            WODI            REAC  \
#
# 124  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 277  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 310  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 109  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 330  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
#
#                JUJO            SWBO            FUCO            MAUP  \
#
# 124  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 277  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 310  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 109  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 330  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
#
#                ORCN         SA_FINAL CUST_ORDR_NO                   \
#                                               cnt              max
# 124  NONE_NONE_NONE          LIDA_ST            1  20247BJ6202889N
# 277  NONE_NONE_NONE          LIDA_ST            1  202479L6199989N
# 310  NONE_NONE_NONE  LBCS_ST-LNOD_ST            2  202540S5900589N
# 109  NONE_NONE_NONE          LIDA_ST            3  20247AK6202539N
# 330  NONE_NONE_NONE  LBCS_ST-LNOD_ST            7  20267GT5959879N
#
#                      ORDR_TYPE_ID         WAITING_NUM            Label
#                  min          cnt max min         cnt max min
# 124  20247BJ6202889N            1  UI  UI           1   0   0  [DS001]
# 277  202479L6199989N            1  S2  S2           1   0   0  [DS001]
# 310  202540S5900439N            2  SA  SA           2   0   0  [DS001]
# 109  202479U6201959N            3  UA  UA           3   0   0  [DS001]
# 330  20267GT5959529N            7  SB  SB           7   0   0  [DS001]

# %%
pna_group_func_agg['Label'] = pna_group_func_agg.apply(lambda row: calculateLabel(row), axis = 1)
pna_group_func_agg.sort_values(['ORRE', 'PRDI', 'LORD', 'PHRD', 'RECO', 'WODI', 'REAC', 'JUJO', 'SWBO', 'FUCO', 'MAUP', 'ORCN', 'SA_FINAL'])
saveDataToCSV("./anal/pna_group_func_agg_E007.csv",pna_group_func_agg)

# %% [markdown]
# ### Anaysis target orders

# %% [markdown]
# ### 미완료 오더 중 진행 중 공정 Zero

# %%
target_df = pna_data_enrich.loc[(pna_data_enrich['ORCN'] == 'NONE_NONE_NONE') & (pna_data_enrich['WAITING_NUM'] == 0)]

# %%
pna_data_group = target_dt_dc002.groupby(['ORDR_TYPE_ID'])['CUST_ORDR_NO', 'PROD_ID']
pna_data_groupAgg = pna_data_group.agg(['count','max','min']).reset_index().sort_values([('CUST_ORDR_NO','count')])
#.sort_values(pna_data_group.get_level_values(1) == 'count')
#column name change
pna_data_groupAgg.rename(columns = {'count': 'cnt'}, inplace = True)

# %%
pna_data_groupAgg.head()
# pna_data_groupAgg.columns = pna_data_groupAgg.columns.to_flat_index()

# %%
pna_data_enrich.loc[(pna_data_enrich['ORCN'] == 'NONE_NONE_NONE') & (pna_data_enrich['WAITING_NUM'] == 0) & (pna_data_enrich['ORDR_TYPE_ID'] == 'SA')]

# %%
### 희망일 초과 오더

# %%
target_dt = pna_data_enrich.loc[(pna_data_enrich['hopeDtSysDtDelta'] < 0) & (pna_data_enrich['ORCN'] == 'NONE_NONE_NONE')]
target_dt = pna_data_enrich.loc[(pna_data_enrich['WAITING_NUM'] == 0) & (pna_data_enrich['ORCN'] == 'NONE_NONE_NONE') & (pna_data_enrich['sysDtLastExecDtDelta'] > 10 )]

# %%
target_dt = target_dt.sort_values(by = ['LOB', 'ORDR_TYPE_ID', 'sysDtLastExecDtDelta','CUST_ORDR_NO'])
target_dt.head()

# %% [markdown]
# ## Common defect

# %%
# DC001-ORRE Only completed
target_dt_dc001 = pna_data_enrich.loc[(pna_data_enrich['ORRE'].isin(['ORRE_2_OKEY', 'ORRE_2_OKEY-ORRE_2_OKEY']))  & (pna_data_enrich['PRDI'] == 'NONE_NONE_NONE') & (pna_data_enrich['LORD'] == 'NONE_NONE_NONE')  & (pna_data_enrich['REAC'] == 'NONE_NONE_NONE')
                & (pna_data_enrich['PHRD'] == 'NONE_NONE_NONE')  & (pna_data_enrich['WODI'] == 'NONE_NONE_NONE') & (pna_data_enrich['RECO'] == 'NONE_NONE_NONE')  
                 & (pna_data_enrich['FUCO'] == 'NONE_NONE_NONE') & (pna_data_enrich['MAUP'] == 'NONE_NONE_NONE')]

# DC002-No in-progress component
target_dt_dc002 = pna_data_enrich.loc[(pna_data_enrich['sysDtLastExecDtDelta'] > 10) & (pna_data_enrich['WAITING_NUM'] == 0) & (pna_data_enrich['SA'] == 'NONE') & (pna_data_enrich['ORCN'] == 'NONE_NONE_NONE')
                                     & ~(pna_data_enrich['ORDR_TYPE_ID'].isin(['AW', 'BA','BQ','KF', 'QA']))
                                     ]
target_dt_dc002[target_dt_dc002['LOB']=='PSTN']

# %% [markdown]
# ## LOB

# %% [markdown]
# ## 1.1 Internet

# %%
pna_data_enrich_int = pna_data_enrich.loc[(pna_data_enrich['LOB'] == 'INTERNET') & (~pna_data_enrich['ORDR_TYPE_ID'].isin(['XV', 'XQ', 'ON', 'XP']))]
pna_data_group = pna_data_enrich_int.groupby(['ORDR_TYPE_ID'])['CUST_ORDR_NO', 'PROD_ID']
pna_data_groupAgg = pna_data_group.agg(['count','max','min']).reset_index().sort_values([('CUST_ORDR_NO','count')])
pna_data_groupAgg.rename(columns = {'count': 'cnt'}, inplace = True)

# %% [markdown]
# ### SOIP for labeling

# %%
# defect list
# 1 ORRE Only
target_dt_d1 = target_dt.loc[(pna_data['ORRE'] == 'ORRE_2_OKEY')  & (pna_data['PRDI'] == 'NONE_NONE_NONE') & (pna_data['LORD'] == 'NONE_NONE_NONE')  & (pna_data['REAC'] == 'NONE_NONE_NONE')
                & (pna_data['PHRD'] == 'NONE_NONE_NONE')  & (pna_data['WODI'] == 'NONE_NONE_NONE') & (pna_data['RECO'] == 'NONE_NONE_NONE')  
                 & (pna_data['FUCO'] == 'NONE_NONE_NONE') & (pna_data['MAUP'] == 'NONE_NONE_NONE')]

target_dt_d1

# %%
target_dt_sa = target_dt.loc[(pna_data_enrich['ORDR_TYPE_ID'] == 'SA')]

# %%
target_dt_sa.group = target_dt_sa.groupby(['ORRE', 'PRDI', 'LORD', 'PHRD', 'RECO', 'WODI', 'REAC', 'JUJO', 'SWBO','FUCO', 'MAUP', 'ORCN'])

# %%
target_data_group = target_dt_sa.groupby(['ORRE', 'PRDI', 'LORD', 'PHRD', 'RECO', 'WODI', 'REAC', 'JUJO', 'SWBO','FUCO', 'MAUP', 'ORCN', 'SA'])['CUST_ORDR_NO','ORDR_TYPE_ID','PROD_ID']
target_data_groupAgg = target_data_group.agg(['count','max','min']).reset_index().sort_values([('CUST_ORDR_NO', 'count')])
#column name change
target_data_groupAgg.rename(columns = {'count': 'cnt'}, inplace = True)

target_data_groupAgg

# %% [markdown]
# # Common analysis tools

# %%
pna_data_enrich
# Out:
#                QUERY_DATE     CUST_ORDR_NO  CUST_ORDR_VER_NO  \
# 0     2020-09-28 13:41:45  11231G318317191                 1
# 1     2020-09-28 13:41:45  14120A001721891                 2
# 2     2020-09-28 13:41:45  14129G007399991                 5
# 3     2020-09-28 13:41:45  14142A107439590                 4
# 4     2020-09-28 13:41:45  14163H208605591                 1
# 5     2020-09-28 13:41:45  14177A408541091                 1
# 6     2020-09-28 13:41:45  14177A408541391                 1
# 7     2020-09-28 13:41:45  14267G557145990                 4
# 8     2020-09-28 13:41:45  1430394046669A0                12
# 9     2020-09-28 13:41:45  15086B417732891                 1
# 10    2020-09-28 13:41:45  16GCN2930069190                 1
# 11    2020-09-28 13:41:45  16GCT2930069190                 1
# 17           18051F9666926-62032259541-57  INTERNET           OE      065759
# 18              18085FJ067720-11350499020      IPTV           VB         NaN
# 19              18144AN923235-65040145536  INTERNET           OA         NaN
# 20              182359F236283-10801550850  INTERNET           X2         NaN
# 21              1823691276130-65047652923  INTERNET           OB         NaN
# 22              182569D790693-11785454710  INTERNET           X2          62
# 23              18268AF869595-10766811170  INTERNET           O2         NaN
# 24              182729V010522-13038434560  INTERNET           X2         NaN
# 25              182759V213558-10259061920  INTERNET           O2         NaN
# 26              18296FD339394-66052287306  INTERNET           OB         NaN
# 27              19051GC412144-67064117674      IPTV           VA         NaN
# 28                        190819V1281949N       IOT           UA          12
# 29                        19150EP9469599N       IOT           UA         NaN
# 30              19156HM655360-66069786522      IPTV           VA         NaN
# 31              19245BM615383-62022895932      IPTV           VC        5559
# 32           19261AO075995-65049051357-57      IPTV           VE      415759
# 33              19261DU368756-69075928944      IPTV           VA         NaN
# 34     19267GW878792-61077179923-Reversal      IPTV           VA         NaN
# 35                19332BC54706991-1091288      PSTN           B1         NaN
# 36                        19345HO5994479N       IOT           UA         NaN
# 37                        19345HU5994519N       IOT           UA         NaN
# 38                        19354FF5402369N       IOT           UB         NaN
# 39                        19360GK4003719N      SOIP           SA        1219
# 40           19361FT807546-64070887873-57      IPTV           VE      415759
# 41     200105D109086-17003802690-Reversal      IPTV           VA         NaN
# 42                        20017JX0467819N      SOIP           SA         NaN
# 43              20023BO952730-69085719208      IPTV           VA         NaN
# 44              20037DQ697060-67089558152  INTERNET           OA         NaN
# 45              20049AN799210-65087010369  INTERNET           OA         NaN
# 46              20055DH380064-63044273058      IPTV           VC      415559
# 47                20072GL80520091-1122459      PSTN           B1         NaN
# 48                        20083GA9276159N      SOIP           SI      020322
# 49              20085EO935277-63089594920      IPTV           VA         NaN
# ...                                   ...       ...          ...         ...
# 9967            20269GP512592-64030074053      IPTV           VI          22
# 9968            20269HB512951-20144467070  INTERNET           XI        1839
# 9969                      20269HL5975409N      SOIP           SA         NaN
# 9970            20269HR512955-10414024490  INTERNET           OB         NaN
# 9971   20269HR512955-10414024490-Reversal  INTERNET           OA         NaN
# 9972            20269IF512962-60013172350  INTERNET           XI          18
# 9973            20269IJ512963-21968760290  INTERNET           XI          18
# 9974                      20269K15129679N       IOT           U2         NaN
# 9975                      202705K4872949N      SOIP           S2         NaN
# 9976                      202709A4875769N      SOIP           S2         NaN
# 9977                      202709D4878349N      SOIP           S2          07
# 9978                      202709G4879829N      SOIP           S2          07
# 9979                      202709G4879849N      SOIP           S2          07
# 9980                      202709G4879869N      SOIP           S2          07
# 9981                      202709G4879889N      SOIP           S2          07
# 9982                      202709G4879909N      SOIP           S2          07
# 9983                      202709G4879929N      SOIP           S2          07
# 9984                      202709H4880389N      SOIP           S2          07
# 9985                      202709I4881449N      SOIP           S2          07
# 9986                      202709I4881469N      SOIP           S2          07
# 9987                      202709J4882009N      SOIP           S2         NaN
# 9988                      20270K14884269N       IOT           U2         NaN
# 9989                      20270K14884309N       IOT           U2         NaN
# 9990                      20270K14884349N       IOT           U2         NaN
# 9991                      20270K14884389N       IOT           U2         NaN
# 9992                      20270K14884469N       IOT           U2         NaN
# 9993                      202719E1016069N      SOIP           S2         NaN
# 9994                      202719F1016209N      SOIP           S2         NaN
# 9995                      202719H1017589N      SOIP           S2         NaN
# 9996                      202729A6473079N      SOIP           S2         NaN
# 9997                      202729C6474319N      SOIP           S2         NaN
# 9998                      202729C6474409N      SOIP           S2         NaN
# 9999                      202729E6475229N      SOIP           S2         NaN
# 10000                     202729E6475269N      SOIP           S2         NaN
# 10001                     202729G6476429N      SOIP           S2         NaN
# 10002                     202729G6476729N      SOIP           S2         NaN
# 10003                     20272AD6481019N      SOIP           SA          10
# 10004                  20272AD6481019N-10      SOIP           SB          10
# 10005           20272AS648105-65053461870      IPTV           VB         NaN
# 10006           20272AV648107-68053535072  INTERNET           OB         NaN
# 10007                     20272B86481089N      SOIP           SA         NaN
# 10008                         R02471TG872  INTERNET         TGRG         NaN
# 10009                         R02471TG873  INTERNET         TGRG         NaN
# 10010                         R02471TG874  INTERNET         TGRG         NaN
# 10012                         R02471TL132      PSTN         TLRL         NaN
# 10015                         R02471TT279      PSTN           TT         NaN
# 10016                     SUSPDAIPTV40601      IPTV           VA         NaN
# 10017                     SUSPDAIPTV80021      IPTV           VA         NaN
# 10018                     SUSPDAIPTV80280      IPTV           VA         NaN
# 10019                     TESTSLCLI603052      IPTV           V1         NaN
#
#       PROD_ID                    PROD_ORDR_SEQ OBDNG_ID       FIRST_CRET_DT  \
# 0        0V02                   10-10557349041   R00432 2020-09-09 14:04:01
# 1        099S           10-11216267011-1065192   R02471 2014-05-06 07:36:28
# 2        099S           10-11218253031-1065281   R02471 2014-05-09 16:04:43
# 3        099S                   10-18646433090   R02471 2014-05-22 10:11:02
# 4        099S           10-11227430081-1065613   R02471 2014-06-12 17:19:46
# 5        099S           10-11188064451-1055586   R02471 2014-06-26 10:41:19
# 6        099S           10-11188064481-1055589   R02471 2014-06-26 10:41:21
# 7        099S                   10-10715999960   R00436 2014-09-24 16:55:39
# 8        0822                   20-12017256550   R03457 2020-09-16 18:16:50
# 9        099S           10-11188292911-1000360   R02402 2015-03-27 11:47:53
# 10       099S                   10-04196006660   R03781 2016-10-19 17:21:40
# 11       099S                   10-04196006660   R03781 2016-10-19 17:21:41
# 12       088W                   10-18137700880   R02471 2017-02-21 09:43:36
# 13       088L                   10-21272191670   R00515 2020-09-02 17:55:56
# 14       099S                   10-11430261180   R00166 2017-06-04 16:12:14
# 15       0501  10-11591701771-1122012-Reversal   R00436 2020-09-15 16:04:07
# 16       099S                   10-11386921470   R00444 2017-12-07 17:13:02
# 17       088L                   20-62032259541   R02471 2018-02-20 15:09:31
# 18       0701                   10-11350499020   R01044 2018-03-26 15:28:16
# 19       088L                   10-65040145536   R02471 2018-05-24 10:37:43
# 20       0784                   10-10801550850   R00439 2018-08-23 09:20:44
# 21       099W                   10-65047652923   R00439 2018-08-24 09:02:02
# 22       0784                   10-11785454710   R00439 2018-09-13 09:16:21
# 23       0822                   10-10766811170   R00439 2018-09-25 10:20:53
# 10016 2099-12-31 23:59:59 2020-09-16 14:31:48              ORRE_2_OKEY
# 10017 2099-12-31 23:59:59 2020-09-16 17:41:08              ORRE_2_OKEY
# 10018 2099-12-31 23:59:59 2020-09-16 17:43:22              ORRE_2_OKEY
# 10019 2020-09-17 18:36:50 2020-09-17 18:36:47              ORRE_2_OKEY
#
#                           PRDI            LORD            PHRD  \
# 0                  PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 1                  PRDI_2_OKEY     LORD_2_OKEY     PHRD_2_OKEY
# 2                  PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# 3                  PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# 4                  PRDI_2_OKEY     LORD_2_OKEY     PHRD_2_OKEY
# 5                  PRDI_2_OKEY     LORD_2_OKEY     PHRD_2_OKEY
# 6                  PRDI_2_OKEY     LORD_2_OKEY     PHRD_2_OKEY
# 7                  PRDI_2_OKEY     LORD_2_OKEY     PHRD_2_OKEY
# 8      PRDI_0_OKEY-PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 9                  PRDI_2_OKEY     LORD_2_OKEY     PHRD_2_OKEY
# 10                 PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# 11                 PRDI_2_OKEY  LORD_3_LORD810  NONE_NONE_NONE
# 12                 PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# 13                 PRDI_2_OKEY  LORD_3_LORD035  NONE_NONE_NONE
# 14                 PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# 15                 PRDI_2_OKEY  LORD_3_LORD997  NONE_NONE_NONE
# 16                 PRDI_2_OKEY     LORD_7_OKEY  NONE_NONE_NONE
# 17                 PRDI_2_OKEY     LORD_7_OKEY  NONE_NONE_NONE
# 18                 PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# 19                 PRDI_2_OKEY     LORD_2_OKEY     PHRD_2_OKEY
# 20                 PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# 21                 PRDI_2_OKEY     LORD_2_OKEY     PHRD_2_OKEY
# 22                 PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# 23                 PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# 24                 PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# 25                 PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# 26                 PRDI_2_OKEY     LORD_7_OKEY  NONE_NONE_NONE
# 27                 PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# 28                 PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# 29                 PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# 30                 PRDI_0_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# 31                 PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 32                 PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 33                 PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# 34                 PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# 35                 PRDI_2_OKEY     LORD_2_OKEY     PHRD_2_OKEY
# 36                 PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# 37                 PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# 38                 PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# 39                 PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# 40                 PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 41                 PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 42                 PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# 43                 PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# 44                 PRDI_2_OKEY     LORD_2_OKEY     PHRD_2_OKEY
# 45                 PRDI_2_OKEY  LORD_3_LORD999  NONE_NONE_NONE
# 46                 PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 47                 PRDI_2_OKEY     LORD_2_OKEY     PHRD_2_OKEY
# 48              NONE_NONE_NONE     LORD_2_OKEY  NONE_NONE_NONE
# 49                 PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# ...                        ...             ...             ...
# 9967               PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 9968               PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 9969               PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# 9970               PRDI_2_OKEY     LORD_2_OKEY     PHRD_2_OKEY
# 9971               PRDI_2_OKEY  LORD_3_LORD600  NONE_NONE_NONE
# 9972               PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 9973               PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 9974               PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 9975               PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 9976               PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 9977               PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 9978               PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 9979               PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 9980               PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 9981               PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 9982               PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 9983               PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 9984               PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 9985               PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 9986               PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 9987               PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 9988               PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 9989               PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 9990               PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 9991               PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 9992               PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# 9993               PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# 9994               PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 9995               PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# 9996               PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 9997               PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 9998               PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 9999               PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 10000              PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 10001              PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 10002              PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 10003              PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 10004              PRDI_0_OKEY  NONE_NONE_NONE  NONE_NONE_NONE
# 10005              PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# 10006              PRDI_2_OKEY  LORD_3_LORD035  NONE_NONE_NONE
# 10007              PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# 10008           NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 10009           NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 10010           NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 10012           NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 10015           NONE_NONE_NONE  NONE_NONE_NONE  NONE_NONE_NONE
# 10016              PRDI_2_OKEY  LORD_3_LORD997  NONE_NONE_NONE
# 10017              PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# 10018              PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
# 10019              PRDI_2_OKEY     LORD_2_OKEY  NONE_NONE_NONE
#
#                  RECO            WODI                     REAC  \
# 0      NONE_NONE_NONE  NONE_NONE_NONE           NONE_NONE_NONE
# 1         RECO_2_OKEY     WODI_2_OKEY           NONE_NONE_NONE
# 2         RECO_2_OKEY     WODI_2_OKEY           NONE_NONE_NONE
# 3         RECO_0_OKEY     WODI_2_OKEY           NONE_NONE_NONE
# 4         RECO_7_OKEY     WODI_2_OKEY           NONE_NONE_NONE
# 5         RECO_7_OKEY     WODI_2_OKEY           NONE_NONE_NONE
# 6         RECO_7_OKEY     WODI_7_OKEY           NONE_NONE_NONE
# 7      NONE_NONE_NONE  NONE_NONE_NONE              REAC_6_OKEY
# 8      NONE_NONE_NONE  NONE_NONE_NONE           NONE_NONE_NONE
# 9         RECO_0_OKEY     WODI_2_OKEY              REAC_2_OKEY
# 10     NONE_NONE_NONE  NONE_NONE_NONE              REAC_6_OKEY
# 11     NONE_NONE_NONE  NONE_NONE_NONE           NONE_NONE_NONE
# 12     NONE_NONE_NONE  NONE_NONE_NONE           NONE_NONE_NONE
# 13     NONE_NONE_NONE  NONE_NONE_NONE           NONE_NONE_NONE
# 14     NONE_NONE_NONE  NONE_NONE_NONE              REAC_6_OKEY
# 15     NONE_NONE_NONE  NONE_NONE_NONE           NONE_NONE_NONE
# 16     NONE_NONE_NONE  NONE_NONE_NONE           NONE_NONE_NONE
# 17     NONE_NONE_NONE  NONE_NONE_NONE           NONE_NONE_NONE
# 18     NONE_NONE_NONE  NONE_NONE_NONE           NONE_NONE_NONE
# 19        RECO_2_OKEY     WODI_2_OKEY           NONE_NONE_NONE
# 20     NONE_NONE_NONE  NONE_NONE_NONE              REAC_2_OKEY
# 21     NONE_NONE_NONE     WODI_2_OKEY              REAC_2_OKEY
# 22     NONE_NONE_NONE  NONE_NONE_NONE              REAC_2_OKEY
# 23     NONE_NONE_NONE  NONE_NONE_NONE              REAC_2_OKEY
# 24     NONE_NONE_NONE  NONE_NONE_NONE              REAC_2_OKEY
# 25     NONE_NONE_NONE  NONE_NONE_NONE              REAC_2_OKEY
# 26     NONE_NONE_NONE     WODI_9_OKEY           NONE_NONE_NONE
# 27     NONE_NONE_NONE     WODI_6_OKEY              REAC_2_OKEY
# 28     NONE_NONE_NONE     WODI_2_OKEY           NONE_NONE_NONE
# 29     NONE_NONE_NONE     WODI_6_OKEY           NONE_NONE_NONE
# 30     NONE_NONE_NONE     WODI_6_OKEY              REAC_2_OKEY
# 31     NONE_NONE_NONE  NONE_NONE_NONE           NONE_NONE_NONE
# 32     NONE_NONE_NONE  NONE_NONE_NONE           NONE_NONE_NONE
# 33     NONE_NONE_NONE  NONE_NONE_NONE           REAC_3_REAC044
# 34     NONE_NONE_NONE     WODI_2_OKEY              REAC_2_OKEY
# 35        RECO_0_OKEY     WODI_2_OKEY           NONE_NONE_NONE
# 36     NONE_NONE_NONE     WODI_6_OKEY           NONE_NONE_NONE
# 37     NONE_NONE_NONE     WODI_6_OKEY           NONE_NONE_NONE
# 38     NONE_NONE_NONE     WODI_2_OKEY           NONE_NONE_NONE
# 39     NONE_NONE_NONE     WODI_6_OKEY              REAC_2_OKEY
# 40     NONE_NONE_NONE  NONE_NONE_NONE           NONE_NONE_NONE
# 41     NONE_NONE_NONE  NONE_NONE_NONE           NONE_NONE_NONE
# 42     NONE_NONE_NONE     WODI_6_OKEY              REAC_2_OKEY
# 43     NONE_NONE_NONE     WODI_2_OKEY              REAC_2_OKEY
# 44        RECO_0_OKEY     WODI_2_OKEY           NONE_NONE_NONE
# 45     NONE_NONE_NONE  NONE_NONE_NONE           NONE_NONE_NONE
# 46     NONE_NONE_NONE  NONE_NONE_NONE           NONE_NONE_NONE
# 47        RECO_0_OKEY     WODI_2_OKEY           NONE_NONE_NONE
# 48     NONE_NONE_NONE     WODI_5_OKEY           NONE_NONE_NONE
# 49     NONE_NONE_NONE     WODI_2_OKEY              REAC_2_OKEY
# ...               ...             ...                      ...
# 9967   NONE_NONE_NONE  NONE_NONE_NONE           NONE_NONE_NONE
# 9968   NONE_NONE_NONE  NONE_NONE_NONE           NONE_NONE_NONE
# 9969   NONE_NONE_NONE  NONE_NONE_NONE              REAC_2_OKEY
# 9970   NONE_NONE_NONE  NONE_NONE_NONE              REAC_6_OKEY
# 9971   NONE_NONE_NONE  NONE_NONE_NONE           NONE_NONE_NONE
# 9972   NONE_NONE_NONE  NONE_NONE_NONE           NONE_NONE_NONE
# 9973   NONE_NONE_NONE  NONE_NONE_NONE           NONE_NONE_NONE
# ...
# 24                 ORCN_2_OKEY                  LIDA_ST-            0
# 25                 ORCN_2_OKEY                  LIDA_ST-            0
# 26                 ORCN_2_OKEY  LIDA_ST-LIDA_CP-LIDA_CP-            0
# 27              NONE_NONE_NONE          LIDA_ST-LPVS_ST-            2
# 28                 ORCN_2_OKEY                  LIDA_ST-            0
# 29              NONE_NONE_NONE                  LIDA_ST-            2
# 30              NONE_NONE_NONE  LIDA_ST-LPVS_ST-LIDA_CP-            3
# 31              NONE_NONE_NONE                  LIDA_ST-            1
# 32              NONE_NONE_NONE                  LIDA_ST-            1
# 33              NONE_NONE_NONE    LIDA_ST-LPVS_PVSE5107-            1
# 34                 ORCN_2_OKEY  LIDA_ST-LPVS_ST-LPVS_ST-            0
# 35              NONE_NONE_NONE                      NONE            1
# 36              NONE_NONE_NONE                  LIDA_ST-            2
# 37              NONE_NONE_NONE                      NONE            2
# 38                 ORCN_2_OKEY          LIDA_ST-LIDA_CP-            0
# 39              NONE_NONE_NONE                  LBCS_ST-            2
# 40              NONE_NONE_NONE                  LIDA_ST-            1
# 41              NONE_NONE_NONE                  LIDA_ST-            1
# 42              NONE_NONE_NONE                  LIDA_ST-            2
# 43              NONE_NONE_NONE          LIDA_ST-LMEN_ST-            1
# 44              NONE_NONE_NONE                  LIDA_ST-            1
# 45              NONE_NONE_NONE                  LIDA_ST-            1
# 46              NONE_NONE_NONE                  LIDA_ST-            1
# 47              NONE_NONE_NONE                      NONE            1
# 48              NONE_NONE_NONE                  LBCS_ST-            2
# 49              NONE_NONE_NONE          LIDA_ST-LMEN_ST-            1
# ...                        ...                       ...          ...
# 9967            NONE_NONE_NONE                  LIDA_ST-            1
# 9968            NONE_NONE_NONE                  LIDA_ST-            1
# 9969            NONE_NONE_NONE                  LIDA_ST-            1
# 9970            NONE_NONE_NONE                  LIDA_ST-            2
# 9971            NONE_NONE_NONE                  LIDA_ST-            1
# 9972            NONE_NONE_NONE                  LIDA_ST-            1
# 9973            NONE_NONE_NONE                  LIDA_ST-            1
# 9974            NONE_NONE_NONE                  LIDA_ST-            1
# 9975            NONE_NONE_NONE                  LIDA_ST-            1
# 9976            NONE_NONE_NONE                  LIDA_ST-            1
# 9977            NONE_NONE_NONE                  LBCS_ST-            1
# 9978            NONE_NONE_NONE                  LBCS_ST-            1
# 9979            NONE_NONE_NONE                  LBCS_ST-            1
# 9980            NONE_NONE_NONE                  LBCS_ST-            1
# 9981            NONE_NONE_NONE                  LBCS_ST-            1
# 9982            NONE_NONE_NONE                  LBCS_ST-            1
# 9983            NONE_NONE_NONE                  LBCS_ST-            1
# 9984            NONE_NONE_NONE                  LBCS_ST-            1
# 9985            NONE_NONE_NONE                  LBCS_ST-            1
# 9986            NONE_NONE_NONE                  LBCS_ST-            1
# 9987            NONE_NONE_NONE                  LBCS_ST-            1
# 9988            NONE_NONE_NONE                  LIDA_ST-            1
# 9989            NONE_NONE_NONE                  LIDA_ST-            1
# 9990            NONE_NONE_NONE                  LIDA_ST-            1
# 9991            NONE_NONE_NONE                  LIDA_ST-            1
# 9992            NONE_NONE_NONE                  LIDA_ST-            0
# 9993               ORCN_2_OKEY                  LIDA_ST-            0
# 9994            NONE_NONE_NONE                  LIDA_ST-            1
# 9995               ORCN_2_OKEY                  LIDA_ST-            0
# 9996            NONE_NONE_NONE                  LIDA_ST-            1
# 9997            NONE_NONE_NONE                  LIDA_ST-            1
# 9998            NONE_NONE_NONE                  LIDA_ST-            1
# 9999            NONE_NONE_NONE                  LIDA_ST-            1
# 10000           NONE_NONE_NONE                  LIDA_ST-            1
# 10001           NONE_NONE_NONE                  LIDA_ST-            1
# 10002           NONE_NONE_NONE                  LIDA_ST-            1
# 10003           NONE_NONE_NONE          LBCS_ST-LNOD_ST-            1
# 10004           NONE_NONE_NONE                  LBCS_ST-            1
# 10005           NONE_NONE_NONE    LIDA_ST-LMEN_MENE0005-            0
# 10006           NONE_NONE_NONE                  LIDA_ST-            1
# 10007           NONE_NONE_NONE                  LIDA_ST-            1
# 10008  ORCN_2_OKEY-ORCN_2_OKEY                      NONE            0
# 10009  ORCN_2_OKEY-ORCN_2_OKEY                      NONE            0
# 10010              ORCN_2_OKEY                      NONE            2
# 10012           NONE_NONE_NONE                      NONE            2
# 10015              ORCN_2_OKEY                      NONE            0
# 10016           NONE_NONE_NONE    LIDA_ST-LMEN_MENE0004-            2
# 10017           NONE_NONE_NONE    LIDA_ST-LMEN_MENE0004-            2
# 10018           NONE_NONE_NONE    LIDA_ST-LMEN_MENE0004-            1
# 10019              ORCN_2_OKEY          LIDA_ST-LMEN_ST-            0
#
#                     SA_FINAL  sysDtLastChgDtDelta  sysDtLastExecDtDelta  \
# 0                    LIDA_CP              27337.0               27337.0
# 1                       NONE               5915.0             2649771.0
# 2                       NONE              10280.0             2594505.0
# 3                    LIDA_CP              19903.0             2989082.0
# 4                       NONE              10264.0             3224412.0
# 5                       NONE              10256.0             2485446.0
# 6                       NONE              10255.0             3292018.0
# 7                    LIDA_ST              17504.0             2858325.0
# 8                       NONE              17004.0               17004.0
# 9                       NONE               5574.0                5669.0
# 10                   LIDA_ST              37340.0             1804124.0
# 11                   LIDA_ST              37340.0             1804128.0
# 12                   LIDA_ST              17157.0              187338.0
# 13                   LIDA_ST              37185.0               37185.0
# 14                      NONE              30156.0             1582546.0
# 15                      NONE              18577.0               18577.0
# 16                   LIDA_ST              40197.0             1465809.0
# 17                   LIDA_CP              20006.0             1369347.0
# 18     LIDA_ST-LMEN_MENE0005              17046.0               17046.0
# 19                   LIDA_CP              17413.0               17413.0
# 20                   LIDA_ST              30038.0               30038.0
# 21                   LIDA_CP              30038.0               30038.0
# 22                   LIDA_ST              30037.0               30038.0
# 23                   LIDA_ST              30037.0               30038.0
# 24                   LIDA_ST              30038.0               30038.0
# 25                   LIDA_ST              30037.0               30038.0
# 26                   LIDA_CP               7002.0              490851.0
# 27                   LIDA_ST               5893.0              843685.0
# 28                   LIDA_ST              24694.0               24694.0
# 29                   LIDA_ST               5903.0              701220.0
# 30                   LIDA_CP               7010.0              685199.0
# 31                   LIDA_ST               5554.0                5554.0
# 32                   LIDA_ST               5553.0                5553.0
# 33                   LIDA_ST              16062.0              541428.0
# 34                   LIDA_ST               7007.0                7007.0
# 35                      NONE              27119.0               27119.0
# 36                   LIDA_ST               7006.0              420242.0
# 37                      NONE               5901.0              418421.0
# 38                   LIDA_CP              17406.0               17406.0
# 39                   LBCS_ST               7006.0              370901.0
# 40                   LIDA_ST               5554.0                5554.0
# 41                   LIDA_ST              15478.0               15478.0
# 42                   LIDA_ST               6999.0              366824.0
# 43           LIDA_ST-LMEN_ST              26091.0               26091.0
# 44                   LIDA_ST              15823.0               17168.0
# 45                   LIDA_ST              17535.0              321302.0
# 46                   LIDA_ST               5556.0                5556.0
# 47                      NONE              27203.0               27203.0
# 48                   LBCS_ST               5900.0              139504.0
# 49           LIDA_ST-LMEN_ST              27143.0               27143.0
# ...                      ...                  ...                   ...
# 9967                 LIDA_ST               4140.0                4140.0
# 9968                 LIDA_ST               4108.0                4108.0
# 9969                 LIDA_ST               4087.0                4087.0
# 9970                 LIDA_ST               4075.0                4075.0
# 9971                 LIDA_ST               4054.0                4054.0
# 9972                 LIDA_ST               4039.0                4039.0
# 9973                 LIDA_ST               4031.0                4031.0
# 9974                 LIDA_ST               3940.0                3940.0
# 9975                 LIDA_ST               3143.0                3143.0
# 9976                 LIDA_ST               3143.0                3143.0
# 9977                 LBCS_ST               3143.0                3143.0
# 9978                 LBCS_ST               3139.0                3139.0
# 9979                 LBCS_ST               3139.0                3139.0
# 9980                 LBCS_ST               3138.0                3138.0
# 9981                 LBCS_ST               3138.0                3138.0
# 9982                 LBCS_ST               3138.0                3138.0
# 9983                 LBCS_ST               3138.0                3138.0
# 9984                 LBCS_ST               3137.0                3137.0
# 9985                 LBCS_ST               3134.0                3134.0
# 9986                 LBCS_ST               3134.0                3134.0
# 9987                 LBCS_ST               3132.0                3132.0
# 9988                 LIDA_ST               2500.0                2500.0
# 9989                 LIDA_ST               2499.0                2499.0
# 9990                 LIDA_ST               2484.0                2484.0
# 9991                 LIDA_ST               2484.0                2484.0
# 9992                 LIDA_ST               2483.0                2483.0
# 9993                 LIDA_ST                821.0                 821.0
# 9994                 LIDA_ST               1701.0                1701.0
# 9995                 LIDA_ST                821.0                 821.0
# 9996                 LIDA_ST                263.0                 263.0
# 9997                 LIDA_ST                263.0                 263.0
# 9998                 LIDA_ST                263.0                 263.0
# 9999                 LIDA_ST                262.0                 262.0
# 10000                LIDA_ST                262.0                 262.0
# 10001                LIDA_ST                258.0                 258.0
# 10002                LIDA_ST                257.0                 257.0
# 10003        LBCS_ST-LNOD_ST                201.0                 201.0
# 10004                LBCS_ST                201.0                 201.0
# 10005  LIDA_ST-LMEN_MENE0005                172.0                 172.0
# 10006                LIDA_ST                167.0                 167.0
# 10007                LIDA_ST                152.0                 152.0
# 10008                   NONE              18928.0               18929.0
# 10009                   NONE              18927.0               18928.0
# 10010                   NONE              18920.0               18921.0
# 10012                   NONE              17239.0               17239.0
# 10015                   NONE              17228.0               17228.0
# 10016  LIDA_ST-LMEN_MENE0004              17229.0               17229.0
# 10017  LIDA_ST-LMEN_MENE0004              17040.0               17040.0
# 10018  LIDA_ST-LMEN_MENE0004              17038.0               17038.0
# 10019        LIDA_ST-LMEN_ST              15544.0               15544.0
#
#        hopeDtSysDtDelta
# 0            -4792182.0
# 1            -3290502.0
# 2            -2591382.0
# 3            -3336222.0
# 4            -3308862.0
# 5            -3290502.0
# 6            -3290502.0
# 7            -3161982.0
# 8              -14382.0
# 9            -2897442.0
# 10           -2073381.0
# 11           -2029782.0
# 12           -1899102.0
# 13             -33282.0
# 14           -1745562.0
# 15             -18579.0
# 16           -1477242.0
# 17           -1367802.0
# 18           -1320402.0
# 19           -1232442.0
# 20           -1101882.0
# 21           -1103142.0
# 22           -1071642.0
# 23           -1054362.0
# 24           -1048602.0
# 25           -1044282.0
# 26           -1016502.0
# 27            -840342.0
# 28            -799422.0
# 29            -700122.0
# 30            -684282.0
# 31            -148182.0
# 32             -57522.0
# 33            -542262.0
# 34            -532578.0
# 35            -434682.0
# 36            -417642.0
# 37            -417582.0
# 38            -407382.0
# 39            -365862.0
# 40            -103542.0
# 41             -15479.0
# 42            -365682.0
# 43            -351282.0
# 44            -333882.0
# 45            -318342.0
# 46            -185742.0
# 47            -282042.0
# 48            -272022.0
# 49            -267702.0
# ...                 ...
# 9967            -4182.0
# 9968            -2982.0
# 9969            -4122.0
# 9970            -4062.0
# 9971            -4056.0
# 9972            -4062.0
# 9973            -2742.0
# 9974            -3942.0
# 9975            -3402.0
# 9976            -1722.0
# 9977            -1722.0
# 9978            -1722.0
# 9979            -1722.0
# 9980            -1722.0
# 9981            -1722.0
# 9982            -1722.0
# 9983            -1722.0
# 9984            -1722.0
# 9985            -1722.0
# 9986            -1722.0
# 9987            -1722.0
# 9988            -2502.0
# 9989            -2502.0
# 9990            -2502.0
# 9991            -2502.0
# 9992            -2502.0
# 9993             -282.0
# 9994             -282.0
# 9995             -282.0
# 9996             1158.0
# 9997             1158.0
# 9998             1158.0
# 9999             1158.0
# 10000            1158.0
# 10001            1158.0
# 10002            1158.0
# 10003           43578.0
# 10004           43578.0
# 10005            -162.0
# 10006            -162.0
# 10007            2658.0
# 10008          -24226.0
# 10009          -18929.0
# 10010          -18922.0
# 10012          -17241.0
# 10015          -17231.0
# 10016        -1536462.0
# 10017        -1536462.0
# 10018        -1536462.0
# 10019         -176502.0
#
# [9993 rows x 34 columns]

# %%
# grouping
check_data = pna_data_enrich.loc[(pna_data_enrich['ORRE'] == 'ORRE_2_OKEY')  & (pna_data_enrich['PRDI'] == 'PRDI_2_OKEY') & (pna_data_enrich['LORD'] == 'LORD_2_OKEY')  & (pna_data_enrich['REAC'] == 'NONE_NONE_NONE')
                & (pna_data_enrich['PHRD'] == 'NONE_NONE_NONE')  & (pna_data_enrich['WODI'] == 'WODI_6_OKEY') & (pna_data_enrich['RECO'] == 'NONE_NONE_NONE')  
                 & (pna_data_enrich['FUCO'] == 'NONE_NONE_NONE') & (pna_data_enrich['MAUP'] == 'NONE_NONE_NONE') & (pna_data_enrich['SA_FINAL'] == 'LIDA_CP')].copy()

check_data.head()
# Out:
# Empty DataFrame
# Columns: [QUERY_DATE, CUST_ORDR_NO, CUST_ORDR_VER_NO, ORDR_COMPOSI_IDFY_ID, LOB, ORDR_TYPE_ID, CONUTC, PROD_ID, PROD_ORDR_SEQ, OBDNG_ID, FIRST_CRET_DT, LAST_CHG_DT, OPN_HOPE_DATE, RMVL_HOPE_DATE, ICIS_CMPLN_DATE, LAST_PRCS_EXEC, ORRE, PRDI, LORD, PHRD, RECO, WODI, REAC, JUJO, SWBO, FUCO, MAUP, ORCN, SA, WAITING_NUM, SA_FINAL, sysDtLastChgDtDelta, sysDtLastExecDtDelta, hopeDtSysDtDelta]
# Index: []

# %%
# 주요 데이터 - 오더타입
chk_group_type = check_data.groupby(['ORDR_TYPE_ID'])['CUST_ORDR_NO']
chk_group_type_agg = chk_group_type.agg(['count','max','min']).reset_index().sort_values('count')
chk_group_type_agg.rename(columns = {'count': 'cnt'}, inplace = True)
chk_group_type_agg
# Out:
# Empty DataFrame
# Columns: [ORDR_TYPE_ID, cnt, max, min]
# Index: []

# %%
check_data_keys = check_data.drop(columns=['ORRE', 'PRDI', 'LORD', 'PHRD', 'RECO', 'WODI', 'REAC', 'JUJO', 'SWBO', 'FUCO', 'MAUP', 'ORCN', 'SA'])

# %%
check_data_keys_group = check_data_keys.groupby(['ORDR_TYPE_ID', 'PROD_ID'])

# %%
check_data_keys_group.count()
# Out:
# Empty DataFrame
# Columns: [QUERY_DATE, CUST_ORDR_NO, CUST_ORDR_VER_NO, ORDR_COMPOSI_IDFY_ID, LOB, CONUTC, PROD_ORDR_SEQ, OBDNG_ID, FIRST_CRET_DT, LAST_CHG_DT, OPN_HOPE_DATE, RMVL_HOPE_DATE, ICIS_CMPLN_DATE, LAST_PRCS_EXEC, WAITING_NUM, SA_FINAL, sysDtLastChgDtDelta, sysDtLastExecDtDelta, hopeDtSysDtDelta]
# Index: []

# %% [markdown]
# ### Start of labeling

# %%
pna_data_enrich_label = pna_data_enrich.copy()

# %%
def addTheLabel(row):
    
    label_set = set()
    label_list = list()
    
    labels = pna_group_func_agg.loc[(pna_group_func_agg['LOB'] == row.LOB) &
        (pna_group_func_agg['ORRE'] == row.ORRE)  & (pna_group_func_agg['PRDI'] == row.PRDI) & (pna_group_func_agg['LORD'] == row.LORD)  & (pna_group_func_agg['REAC'] == row.REAC)
                & (pna_group_func_agg['PHRD'] == row.PHRD)  & (pna_group_func_agg['WODI'] == row.WODI) & (pna_group_func_agg['RECO'] == row.RECO)  
                 & (pna_group_func_agg['FUCO'] == row.FUCO) & (pna_group_func_agg['MAUP'] == row.MAUP) & (pna_group_func_agg['SA_FINAL'] == row.SA_FINAL)].Label.tolist()
    
    for i in labels:
        for label in i: 
            label_set.add(label)
    
    return label_set

# %%
pna_data_enrich_label['Label'] = pna_data_enrich_label.apply(lambda row : addTheLabel(row), axis = 1)

# %%
saveDataToCSV("./anal/pna_final_data_v0.1_1.csv",pna_data_enrich_label)

# %%
### Start of machine learning

# %%
# 기본 라이브러리 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# ML 라이브러리
import sklearn
from sklearn.svm import SVC
from sklearn.cluster import KMeans
# from sklearn.logg
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# Dataset
from sklearn.datasets import load_iris
# Encoder

import os

# AICentro
import tensorflow as tf
from tensorflow.python import keras
from tensorflow.python.keras.datasets import mnist
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Dropout
from tensorflow.python.keras.optimizers import RMSprop

# %%
pna_data_enrich_label['CONUTC'].fillna('NONE', inplace = True)

# %%
x_data_col[:-1]
# Out:
# Index(['QUERY_DATE', 'CUST_ORDR_NO', 'CUST_ORDR_VER_NO',
#        'ORDR_COMPOSI_IDFY_ID', 'LOB', 'ORDR_TYPE_ID', 'CONUTC', 'PROD_ID',
#        'PROD_ORDR_SEQ', 'OBDNG_ID', 'FIRST_CRET_DT', 'LAST_CHG_DT',
#        'OPN_HOPE_DATE', 'RMVL_HOPE_DATE', 'ICIS_CMPLN_DATE', 'LAST_PRCS_EXEC',
#        'ORRE', 'PRDI', 'LORD', 'PHRD', 'RECO', 'WODI', 'REAC', 'JUJO', 'SWBO',
#        'FUCO', 'MAUP', 'ORCN', 'SA', 'WAITING_NUM', 'SA_FINAL',
#        'sysDtLastChgDtDelta', 'sysDtLastExecDtDelta'],
#       dtype='object')

# %%
x_data_col = pna_data_enrich_label.columns
x_data_col = ['LOB', 'ORDR_TYPE_ID', 'CONUTC', 'PROD_ID',
       'PROD_ORDR_SEQ', 'ORRE', 'PRDI', 'LORD', 'PHRD', 'RECO', 'WODI', 'REAC', 'JUJO', 'SWBO',
       'FUCO', 'MAUP', 'ORCN', 'SA', 'WAITING_NUM', 'SA_FINAL']
x_data = pna_data_enrich_label[x_data_col]
y_data = pna_data_enrich_label['Label']

# %%
label_set_lob = set(x_data['LOB'])
label_dict_lob = {j : i for i,j in enumerate(label_set_lob)}

label_set_type = set(x_data['ORDR_TYPE_ID'])
label_dict_type= {j : i for i,j in enumerate(label_set_type)}

label_dict_type
# Out:
# {'XB': 0,
#  'V1': 1,
#  'KG': 2,
#  'B1': 3,
#  'VF': 4,
#  'ONOM': 5,
#  'L2': 6,
#  'N2': 7,
#  'WB': 8,
#  'SB': 9,
#  'UI': 10,
#  'J2': 11,
#  'VA': 12,
#  'J1': 13,
#  'XI': 14,
#  'X1': 15,
#  'A2': 16,
#  'XT': 17,
#  'D2': 18,
#  'TGRG': 19,
#  'VC': 20,
#  'VT': 21,
#  'UC': 22,
#  'N3': 23,
#  'BA': 24,
#  'L1': 25,
#  'VE': 26,
#  'OB': 27,
#  'K9': 28,
#  'TLRL': 29,
#  'KZ': 30,
#  'SC': 31,
#  'SI': 32,
#  'S1': 33,
#  'TT': 34,
#  'C1': 35,
#  'E3': 36,
#  'A1': 37,
#  'N1': 38,
#  'X2': 39,
#  'OF': 40,
#  'V2': 41,
#  'EO': 42,
#  'UB': 43,
#  'M1': 44,
#  'O1': 45,
#  'QBQA': 46,
#  'XHXG': 47,
#  'I4': 48,
#  'O2': 49,
#  'SA': 50,
#  'U1': 51,
#  'VI': 52,
#  'OE': 53,
#  'B3': 54,
#  'I6': 55,
#  'OLOK': 56,
#  'S2': 57,
#  'VB': 58,
#  'OA': 59,
#  'UA': 60,
#  'U2': 61}

# %%
x_data['LOB'] = [label_set_lob[i] for i in x_data['LOB'].tolist()]
# x_data['ORDER_TYPE_ID'] = [label_dict_type[i] for i in x_data['ORDER_TYPE_ID'].tolist()]

x_data.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-120-432054158d69> in <module>
# ----> 1 x_data['LOB'] = [label_set_lob[i] for i in x_data['LOB'].tolist()]
#       2 # x_data['ORDER_TYPE_ID'] = [label_dict_type[i] for i in x_data['ORDER_TYPE_ID'].tolist()]
#       3
#       4 x_data.head()
#
# <ipython-input-120-432054158d69> in <listcomp>(.0)
# ----> 1 x_data['LOB'] = [label_set_lob[i] for i in x_data['LOB'].tolist()]
#       2 # x_data['ORDER_TYPE_ID'] = [label_dict_type[i] for i in x_data['ORDER_TYPE_ID'].tolist()]
#       3
#       4 x_data.head()
#
# TypeError: 'set' object is not subscriptable

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data, y_data)

# %%
model = sklearn.svm.LinearSVC()
model.fit(x_train, y_train)

result = model.predict(x_test)
accuracy = metrics.accuracy_score(result, y_test)
accuracy
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-869e72c53817> in <module>
#       1 model = sklearn.svm.LinearSVC()
# ----> 2 model.fit(x_train, y_train)
#       3
#       4 result = model.predict(x_test)
#       5 accuracy = metrics.accuracy_score(result, y_test)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/svm/classes.py in fit(self, X, y, sample_weight)
#     227         X, y = check_X_y(X, y, accept_sparse='csr',
#     228                          dtype=np.float64, order="C",
# --> 229                          accept_large_sparse=False)
#     230         check_classification_targets(y)
#     231         self.classes_ = np.unique(y)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
#     755                     warn_on_dtype=warn_on_dtype,
# --> 756                     estimator=estimator)
#     757     if multi_output:
#     758         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     525             try:
#     526                 warnings.simplefilter('error', ComplexWarning)
# --> 527                 array = np.asarray(array, dtype=dtype, order=order)
#     528             except ComplexWarning:
#     529                 raise ValueError("Complex data not supported\n"
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     499
#     500     """
# --> 501     return array(a, dtype, copy=False, order=order)
#     502
#     503
#
# ValueError: could not convert string to float: 'LBCS_ST-LNOD_ST'
